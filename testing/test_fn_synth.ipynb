# %%
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.functional import normalize
from math import sqrt
from detorch import DE, Policy, Strategy
from detorch.config import default_config, Config
from typing import Type
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('..')
sys.path.append('viz')
from optimneuralts import OptimNeuralTS, LenientOptimNeuralTS
from networks import NetworkDropout
import viz_config
import logging

logging.basicConfig(level=logging.INFO)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
config = Config(default_config)
bounds = [-2.5, 1.5]
theta = torch.Tensor([0, 3, -2, -4, 1, 1]).to(device)
d = 1
torch.set_default_tensor_type("torch.cuda.FloatTensor")

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Classes

# %%
class PullPolicy(Policy):
    def __init__(self, eval_fn):
        super().__init__()
        self.point = torch.FloatTensor(1).uniform_(*bounds).to(device)
        self.params = nn.Parameter(
            self.point, requires_grad=False
        )
        self.eval_fn = eval_fn
        self.ucb = None

    def evaluate(self):
        self.transform()
        ucb, activation_grad, _, _ = self.eval_fn(self.point)
        ucb = ucb.detach().item()
        self.activation_grad = activation_grad
        self.ucb = ucb
        # logging.info(self.point)
        # logging.info(ucb)
        return ucb

    def transform(self):
        self.point = torch.clip(self.params, *bounds).to(device)
        self.params = nn.Parameter(
            self.point, requires_grad=False
        )
        # return generate_feature_vector_from_point(self.point)


class DEConfig:
    n_step: int = 3
    population_size: int = 60
    differential_weight: float = 0.8
    crossover_probability: float = 0.9
    strategy: Strategy = Strategy.best1bin
    seed: int = "does not matter"

# %% [markdown]
# # Utility

# %%
def compute_jaccard(found_solution: set, true_solution: set):
    n_in_inter = 0

    intersection = found_solution & true_solution

    n_in_inter = len(intersection)

    return (
        n_in_inter / (len(found_solution) + len(true_solution) - n_in_inter),
        n_in_inter,
    )
def make_deterministic(seed):
    # PyTorch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

    # Numpy
    np.random.seed(seed)

    # Built-in Python
    random.seed(seed)

def project_point(point):
    return torch.tensor([1, point, point ** 2, point ** 3, point ** 4, point ** 5]).to(device)

def reward_fn(point, add_noise=True):
    noise = torch.normal(0, 1, (1,)).item()

    vec = project_point(point)
    value = theta @ vec.T
    
    return value + add_noise * noise


def gen_warmup_vecs_and_rewards(n_warmup):
    vecs = torch.tensor([])
    rewards = torch.tensor([])
    for i in range(n_warmup):
        point = torch.FloatTensor(1).uniform_(bounds[0], bounds[1]).to(device)
        reward = torch.tensor([reward_fn(point)])

        vecs = torch.cat((vecs, point))
        rewards = torch.cat((rewards, reward))
    vecs = vecs.view((n_warmup, -1))
    rewards = rewards.view((n_warmup, -1))
    return vecs, rewards


def plot_estimate(agent, trial, fn=None, title=""):
    n_points = 1000
    x = np.linspace(-2.5, 1.5, n_points)
    x_vec = []
    y = []
    for x_point in x:
        y.append(reward_fn(float(x_point), add_noise=False).cpu().numpy())

    y_pred = []
    cbs = []
    ucbs = []
    x_tns = torch.from_numpy(x)
    x_tns = x_tns.view(n_points, 1).float()

    for point in x_tns:
        sample, _, activ, cb = agent.get_sample(point.to(device))
        y_pred.append(activ)
        cbs.append(3 * cb)
        ucbs.append(sample)

    y_pred = np.array(y_pred)
    cbs = np.array(cbs)

    point_played = agent.train_dataset.features.squeeze(0).cpu().numpy()
    rewards_rec = agent.train_dataset.rewards.squeeze(0).cpu().numpy()
    n_played = point_played.shape[0]

    # plt.ylim(-20, 10)
    # plt.ylim(-25, 10)
    plt.plot(x, y, color="tab:blue", label="Vraie fonction")
    plt.plot(x, y_pred, color="tab:orange", label="Estimation de la fonction")
    # plt.fill_between(x, y_pred, ucbs, color='tab:red', alpha=0.3)
    plt.fill_between(
        x, y_pred + cbs, y_pred - cbs, alpha=0.3, color="tab:orange", zorder=-1, label="Intervalle de confiance",
    )
    plt.plot(
        x,
        [0] * n_points,
        color="black",
        linestyle="dashed",
        label="Seuil bonne/mauvaise action",
    )
    plt.scatter(
        point_played[:n_played],
        rewards_rec[:n_played],
        color="black",
        alpha=0.5,
        label="Points joués précédemment",
    )
    plt.scatter(
        point_played[-1], rewards_rec[-1], color="green", label="Dernier point joué"
    )

    plt.title(title)
    
    plt.xlabel("$x$")
    plt.ylabel("$y$")


    plt.legend()
    if fn is None:
        filename = f"viz/images/exp_poly/regTS_{n_trials}_trials_expl_{exploration_mult}_trial_{trial}.png"
    else:
        filename = f"viz/images/exp_poly/{fn}.png"
    plt.savefig(filename)

    plt.clf()


def find_best_member(eval_fn, de_config, seed):
    de_config.seed = seed
    config = Config(default_config)

    @config("policy")
    class PolicyConfig:
        policy: Type[Policy] = PullPolicy
        eval_fn: object = agent.get_sample

    config("de")(de_config)

    de = DE(config)
    de.train()

    return de.population[de.current_best]


def gen_mask(example_vec, agent, account=False):
    # Mask for 1 vec
    eval_mask = (
        torch.distributions.Bernoulli(
            torch.full_like(example_vec, (1 - dropout_rate))
        ).sample()
        / (1 - dropout_rate)
    ).to(device)

    n_obs = list(agent.train_dataset.features.shape)[0]

    if account:
        n_obs + 1

    # Mask for multiple vecs
    training_mask = (
        torch.distributions.Bernoulli(
            torch.full((n_obs, agent.net.hidden_size), (1 - dropout_rate))
        ).sample()
        / (1 - dropout_rate)
    ).to(device)

    return eval_mask, training_mask

# %% [markdown]
# # Visualize 1 run

# %%
run = 42
make_deterministic(run)

n_trials = 500
dropout_rate = False
width = 100
net = NetworkDropout(d, width,dropout=dropout_rate).to(device)
reg = 1
exploration_mult = 1
delay = 0
reward_fn = reward_fn
de_config = DEConfig
de_policy = PullPolicy
style="ts"
sampletype="r"
max_n_steps = 100 
agent = OptimNeuralTS(net, nu=exploration_mult, lambda_=reg, style=style, sampletype=sampletype)
# agent = LenientOptimNeuralTS(net, nu=exploration_mult, lambda_=reg, reward_sample_thresholds=[float('-inf'), 0])

# %%
vecs, rewards = gen_warmup_vecs_and_rewards(10)
vecs, rewards = vecs.to(device), rewards.to(device)

example_vec = vecs[0]
# Out:
# /tmp/ipykernel_2418622/1693466289.py:32: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2318.)
#   value = theta @ vec.T

# %%
agent.train_dataset.set_(vecs, rewards)

for vec in vecs:
    activ, grad = agent.compute_activation_and_grad(vec)
    agent.U += grad * grad

agent.net.eval()
agent.train(max_n_steps, patience=max_n_steps, lds=False)
agent.net.train()
# Out:
# NetworkDropout(
#   (fc1): Linear(in_features=1, out_features=100, bias=True)
#   (activate): ReLU()
#   (fc2): Linear(in_features=100, out_features=1, bias=True)
#   (dropout): Identity()
# )

# %%
plot_estimate(agent, 0,  f'{style}_expl_{exploration_mult}_{sampletype}_run{run}_trial_0')
agent.net.train()
# Out:
# NetworkDropout(
#   (fc1): Linear(in_features=1, out_features=100, bias=True)
#   (activate): ReLU()
#   (fc2): Linear(in_features=100, out_features=1, bias=True)
#   (dropout): Identity()
# )

# %% [markdown]
# ### Train 1 run

# %%
for i in range(n_trials):
    agent.net.train()
    best_member = find_best_member(agent.get_sample, de_config, i)
    agent.net.eval()

    best_member_grad = best_member.activation_grad
    a_t = best_member.point.unsqueeze(0)
    r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

    logging.info(f"trial: {i}")

    agent.U += best_member_grad * best_member_grad

    agent.train_dataset.add(a_t, r_t)

    agent.train(max_n_steps, patience=max_n_steps, lds=False)
    if (i + 1) % 100 == 0:
        plot_estimate(
            agent,
            0,
            f"{style}_expl_{exploration_mult}_{sampletype}_run{run}_trial_{i+1}"
        )
# Out:
# INFO:root:trial: 0
# INFO:root:trial: 1
# INFO:root:trial: 2
# INFO:root:trial: 3
# INFO:root:trial: 4
# INFO:root:trial: 5
# INFO:root:trial: 6
# INFO:root:trial: 7
# INFO:root:trial: 8
# INFO:root:trial: 9
# INFO:root:trial: 10
# INFO:root:trial: 11
# INFO:root:trial: 12
# INFO:root:trial: 13
# INFO:root:trial: 14
# INFO:root:trial: 15
# INFO:root:trial: 16
# INFO:root:trial: 17
# INFO:root:trial: 18
# INFO:root:trial: 19
# INFO:root:trial: 20
# INFO:root:trial: 21
# INFO:root:trial: 22
# INFO:root:trial: 23
# INFO:root:trial: 24
# INFO:root:trial: 25
# INFO:root:trial: 26
# INFO:root:trial: 27
# INFO:root:trial: 28
# INFO:root:trial: 29
# INFO:root:trial: 30
# INFO:root:trial: 31
# INFO:root:trial: 32
# INFO:root:trial: 33
# INFO:root:trial: 34
# INFO:root:trial: 35
# INFO:root:trial: 36
# INFO:root:trial: 37
# INFO:root:trial: 38
# INFO:root:trial: 39
# INFO:root:trial: 40
# INFO:root:trial: 41
# INFO:root:trial: 42
# INFO:root:trial: 43
# INFO:root:trial: 44
# INFO:root:trial: 45
# INFO:root:trial: 46
# INFO:root:trial: 47
# INFO:root:trial: 48
# INFO:root:trial: 49
# INFO:root:trial: 50
# INFO:root:trial: 51
# INFO:root:trial: 52
# INFO:root:trial: 53
# INFO:root:trial: 54
# INFO:root:trial: 55
# INFO:root:trial: 56
# INFO:root:trial: 57
# INFO:root:trial: 58
# INFO:root:trial: 59
# INFO:root:trial: 60
# INFO:root:trial: 61
# INFO:root:trial: 62
# INFO:root:trial: 63
# INFO:root:trial: 64
# INFO:root:trial: 65
# INFO:root:trial: 66
# INFO:root:trial: 67
# INFO:root:trial: 68
# INFO:root:trial: 69
# INFO:root:trial: 70
# INFO:root:trial: 71
# INFO:root:trial: 72
# INFO:root:trial: 73
# INFO:root:trial: 74
# INFO:root:trial: 75
# INFO:root:trial: 76
# INFO:root:trial: 77
# INFO:root:trial: 78
# INFO:root:trial: 79
# INFO:root:trial: 80
# INFO:root:trial: 81
# INFO:root:trial: 82
# INFO:root:trial: 83
# INFO:root:trial: 84
# INFO:root:trial: 85
# INFO:root:trial: 86
# INFO:root:trial: 87
# INFO:root:trial: 88
# INFO:root:trial: 89
# INFO:root:trial: 90
# INFO:root:trial: 91
# INFO:root:trial: 92
# INFO:root:trial: 93
# INFO:root:trial: 94
# INFO:root:trial: 95
# INFO:root:trial: 96
# INFO:root:trial: 97
# INFO:root:trial: 98
# INFO:root:trial: 99
# INFO:root:trial: 100
# INFO:root:trial: 101
# INFO:root:trial: 102
# INFO:root:trial: 103
# INFO:root:trial: 104
# INFO:root:trial: 105
# INFO:root:trial: 106
# INFO:root:trial: 107
# INFO:root:trial: 108
# INFO:root:trial: 109
# INFO:root:trial: 110
# INFO:root:trial: 111
# INFO:root:trial: 112
# INFO:root:trial: 113
# INFO:root:trial: 114
# INFO:root:trial: 115
# INFO:root:trial: 116
# INFO:root:trial: 117
# INFO:root:trial: 118
# INFO:root:trial: 119
# INFO:root:trial: 120
# INFO:root:trial: 121
# INFO:root:trial: 122
# INFO:root:trial: 123
# INFO:root:trial: 124
# INFO:root:trial: 125
# INFO:root:trial: 126
# INFO:root:trial: 127
# INFO:root:trial: 128
# INFO:root:trial: 129
# INFO:root:trial: 130
# INFO:root:trial: 131
# INFO:root:trial: 132
# INFO:root:trial: 133
# INFO:root:trial: 134
# INFO:root:trial: 135
# INFO:root:trial: 136
# INFO:root:trial: 137
# INFO:root:trial: 138
# INFO:root:trial: 139
# INFO:root:trial: 140
# INFO:root:trial: 141
# INFO:root:trial: 142
# INFO:root:trial: 143
# INFO:root:trial: 144
# INFO:root:trial: 145
# INFO:root:trial: 146
# INFO:root:trial: 147
# INFO:root:trial: 148
# INFO:root:trial: 149
# INFO:root:trial: 150
# INFO:root:trial: 151
# INFO:root:trial: 152
# INFO:root:trial: 153
# INFO:root:trial: 154
# INFO:root:trial: 155
# INFO:root:trial: 156
# INFO:root:trial: 157
# INFO:root:trial: 158
# INFO:root:trial: 159
# INFO:root:trial: 160
# INFO:root:trial: 161
# INFO:root:trial: 162
# INFO:root:trial: 163
# INFO:root:trial: 164
# INFO:root:trial: 165
# INFO:root:trial: 166
# INFO:root:trial: 167
# INFO:root:trial: 168
# INFO:root:trial: 169
# INFO:root:trial: 170
# INFO:root:trial: 171
# INFO:root:trial: 172
# INFO:root:trial: 173
# INFO:root:trial: 174
# INFO:root:trial: 175
# INFO:root:trial: 176
# INFO:root:trial: 177
# INFO:root:trial: 178
# INFO:root:trial: 179
# INFO:root:trial: 180
# INFO:root:trial: 181
# INFO:root:trial: 182
# INFO:root:trial: 183
# INFO:root:trial: 184
# INFO:root:trial: 185
# INFO:root:trial: 186
# INFO:root:trial: 187
# INFO:root:trial: 188
# INFO:root:trial: 189
# INFO:root:trial: 190
# INFO:root:trial: 191
# INFO:root:trial: 192
# INFO:root:trial: 193
# INFO:root:trial: 194
# INFO:root:trial: 195
# INFO:root:trial: 196
# INFO:root:trial: 197
# INFO:root:trial: 198
# INFO:root:trial: 199
# INFO:root:trial: 200
# INFO:root:trial: 201
# INFO:root:trial: 202
# INFO:root:trial: 203
# INFO:root:trial: 204
# INFO:root:trial: 205
# INFO:root:trial: 206
# INFO:root:trial: 207
# INFO:root:trial: 208
# INFO:root:trial: 209
# INFO:root:trial: 210
# INFO:root:trial: 211
# INFO:root:trial: 212
# INFO:root:trial: 213
# INFO:root:trial: 214
# INFO:root:trial: 215
# INFO:root:trial: 216
# INFO:root:trial: 217
# INFO:root:trial: 218
# INFO:root:trial: 219
# INFO:root:trial: 220
# INFO:root:trial: 221
# INFO:root:trial: 222
# INFO:root:trial: 223
# INFO:root:trial: 224
# INFO:root:trial: 225
# INFO:root:trial: 226
# INFO:root:trial: 227
# INFO:root:trial: 228
# INFO:root:trial: 229
# INFO:root:trial: 230
# INFO:root:trial: 231
# INFO:root:trial: 232
# INFO:root:trial: 233
# INFO:root:trial: 234
# INFO:root:trial: 235
# INFO:root:trial: 236
# INFO:root:trial: 237
# INFO:root:trial: 238
# INFO:root:trial: 239
# INFO:root:trial: 240
# INFO:root:trial: 241
# INFO:root:trial: 242
# INFO:root:trial: 243
# INFO:root:trial: 244
# INFO:root:trial: 245
# INFO:root:trial: 246
# INFO:root:trial: 247
# INFO:root:trial: 248
# INFO:root:trial: 249
# INFO:root:trial: 250
# INFO:root:trial: 251
# INFO:root:trial: 252
# INFO:root:trial: 253
# INFO:root:trial: 254
# INFO:root:trial: 255
# INFO:root:trial: 256
# INFO:root:trial: 257
# INFO:root:trial: 258
# INFO:root:trial: 259
# INFO:root:trial: 260
# INFO:root:trial: 261
# INFO:root:trial: 262
# INFO:root:trial: 263
# INFO:root:trial: 264
# INFO:root:trial: 265
# INFO:root:trial: 266
# INFO:root:trial: 267
# INFO:root:trial: 268
# INFO:root:trial: 269
# INFO:root:trial: 270
# INFO:root:trial: 271
# INFO:root:trial: 272
# INFO:root:trial: 273
# INFO:root:trial: 274
# INFO:root:trial: 275
# INFO:root:trial: 276
# INFO:root:trial: 277
# INFO:root:trial: 278
# INFO:root:trial: 279
# INFO:root:trial: 280
# INFO:root:trial: 281
# INFO:root:trial: 282
# INFO:root:trial: 283
# INFO:root:trial: 284
# INFO:root:trial: 285
# INFO:root:trial: 286
# INFO:root:trial: 287
# INFO:root:trial: 288
# INFO:root:trial: 289
# INFO:root:trial: 290
# INFO:root:trial: 291
# INFO:root:trial: 292
# INFO:root:trial: 293
# INFO:root:trial: 294
# INFO:root:trial: 295
# INFO:root:trial: 296
# INFO:root:trial: 297
# INFO:root:trial: 298
# INFO:root:trial: 299
# INFO:root:trial: 300
# INFO:root:trial: 301
# INFO:root:trial: 302
# INFO:root:trial: 303
# INFO:root:trial: 304
# INFO:root:trial: 305
# INFO:root:trial: 306
# INFO:root:trial: 307
# INFO:root:trial: 308
# INFO:root:trial: 309
# INFO:root:trial: 310
# INFO:root:trial: 311
# INFO:root:trial: 312
# INFO:root:trial: 313
# INFO:root:trial: 314
# INFO:root:trial: 315
# INFO:root:trial: 316
# INFO:root:trial: 317
# INFO:root:trial: 318
# INFO:root:trial: 319
# INFO:root:trial: 320
# INFO:root:trial: 321
# INFO:root:trial: 322
# INFO:root:trial: 323
# INFO:root:trial: 324
# INFO:root:trial: 325
# INFO:root:trial: 326
# INFO:root:trial: 327
# INFO:root:trial: 328
# INFO:root:trial: 329
# INFO:root:trial: 330
# INFO:root:trial: 331
# INFO:root:trial: 332
# INFO:root:trial: 333
# INFO:root:trial: 334
# INFO:root:trial: 335
# INFO:root:trial: 336
# INFO:root:trial: 337
# INFO:root:trial: 338
# INFO:root:trial: 339
# INFO:root:trial: 340
# INFO:root:trial: 341
# INFO:root:trial: 342
# INFO:root:trial: 343
# INFO:root:trial: 344
# INFO:root:trial: 345
# INFO:root:trial: 346
# INFO:root:trial: 347
# INFO:root:trial: 348
# INFO:root:trial: 349
# INFO:root:trial: 350
# INFO:root:trial: 351
# INFO:root:trial: 352
# INFO:root:trial: 353
# INFO:root:trial: 354
# INFO:root:trial: 355
# INFO:root:trial: 356
# INFO:root:trial: 357
# INFO:root:trial: 358
# INFO:root:trial: 359
# INFO:root:trial: 360
# INFO:root:trial: 361
# INFO:root:trial: 362
# INFO:root:trial: 363
# INFO:root:trial: 364
# INFO:root:trial: 365
# INFO:root:trial: 366
# INFO:root:trial: 367
# INFO:root:trial: 368
# INFO:root:trial: 369
# INFO:root:trial: 370
# INFO:root:trial: 371
# INFO:root:trial: 372
# INFO:root:trial: 373
# INFO:root:trial: 374
# INFO:root:trial: 375
# INFO:root:trial: 376
# INFO:root:trial: 377
# INFO:root:trial: 378
# INFO:root:trial: 379
# INFO:root:trial: 380
# INFO:root:trial: 381
# INFO:root:trial: 382
# INFO:root:trial: 383
# INFO:root:trial: 384
# INFO:root:trial: 385
# INFO:root:trial: 386
# INFO:root:trial: 387
# INFO:root:trial: 388
# INFO:root:trial: 389
# INFO:root:trial: 390
# INFO:root:trial: 391
# INFO:root:trial: 392
# INFO:root:trial: 393
# INFO:root:trial: 394
# INFO:root:trial: 395
# INFO:root:trial: 396
# INFO:root:trial: 397
# INFO:root:trial: 398
# INFO:root:trial: 399
# INFO:root:trial: 400
# INFO:root:trial: 401
# INFO:root:trial: 402
# INFO:root:trial: 403
# INFO:root:trial: 404
# INFO:root:trial: 405
# INFO:root:trial: 406
# INFO:root:trial: 407
# INFO:root:trial: 408
# INFO:root:trial: 409
# INFO:root:trial: 410
# INFO:root:trial: 411
# INFO:root:trial: 412
# INFO:root:trial: 413
# INFO:root:trial: 414
# INFO:root:trial: 415
# INFO:root:trial: 416
# INFO:root:trial: 417
# INFO:root:trial: 418
# INFO:root:trial: 419
# INFO:root:trial: 420
# INFO:root:trial: 421
# INFO:root:trial: 422
# INFO:root:trial: 423
# INFO:root:trial: 424
# INFO:root:trial: 425
# INFO:root:trial: 426
# INFO:root:trial: 427
# INFO:root:trial: 428
# INFO:root:trial: 429
# INFO:root:trial: 430
# INFO:root:trial: 431
# INFO:root:trial: 432
# INFO:root:trial: 433
# INFO:root:trial: 434
# INFO:root:trial: 435
# INFO:root:trial: 436
# INFO:root:trial: 437
# INFO:root:trial: 438
# INFO:root:trial: 439
# INFO:root:trial: 440
# INFO:root:trial: 441
# INFO:root:trial: 442
# INFO:root:trial: 443
# INFO:root:trial: 444
# INFO:root:trial: 445
# INFO:root:trial: 446
# INFO:root:trial: 447
# INFO:root:trial: 448
# INFO:root:trial: 449
# INFO:root:trial: 450
# INFO:root:trial: 451
# INFO:root:trial: 452
# INFO:root:trial: 453
# INFO:root:trial: 454
# INFO:root:trial: 455
# INFO:root:trial: 456
# INFO:root:trial: 457
# INFO:root:trial: 458
# INFO:root:trial: 459
# INFO:root:trial: 460
# INFO:root:trial: 461
# INFO:root:trial: 462
# INFO:root:trial: 463
# INFO:root:trial: 464
# INFO:root:trial: 465
# INFO:root:trial: 466
# INFO:root:trial: 467
# INFO:root:trial: 468
# INFO:root:trial: 469
# INFO:root:trial: 470
# INFO:root:trial: 471
# INFO:root:trial: 472
# INFO:root:trial: 473
# INFO:root:trial: 474
# INFO:root:trial: 475
# INFO:root:trial: 476
# INFO:root:trial: 477
# INFO:root:trial: 478
# INFO:root:trial: 479
# INFO:root:trial: 480
# INFO:root:trial: 481
# INFO:root:trial: 482
# INFO:root:trial: 483
# INFO:root:trial: 484
# INFO:root:trial: 485
# INFO:root:trial: 486
# INFO:root:trial: 487
# INFO:root:trial: 488
# INFO:root:trial: 489
# INFO:root:trial: 490
# INFO:root:trial: 491
# INFO:root:trial: 492
# INFO:root:trial: 493
# INFO:root:trial: 494
# INFO:root:trial: 495
# INFO:root:trial: 496
# INFO:root:trial: 497
# INFO:root:trial: 498
# INFO:root:trial: 499

# %% [markdown]
# # Train all runs, for all algos and every exploration

# %%
x_arr = np.linspace(-2.5, 1.5, 1000)
x_arr = x_arr.reshape(1000, 1)
x = torch.from_numpy(x_arr).to(device).float()
y = []
for point in x:
    y.append(reward_fn(point, add_noise=False).cpu().numpy())

y = np.array(y)
true_sol_idx = np.where(y >= 0)[0]
true_sol = x[true_sol_idx].to(device).float()
true_sol_idx = set(true_sol_idx.tolist())

n_true_sol = len(true_sol)
logging.info(n_true_sol)
n_sigmas = 3
# Out:
# INFO:root:419

# %%
metrics_dict = {}
algos = ["UCB", "regTS", "lenientTS"]
# algos = ["lenientTS"]
exploration_mults = [1, 10]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for exploration_mult in exploration_mults:
        metrics_dict[algo][str(exploration_mult)] = {}
        metrics_dict[algo][str(exploration_mult)]["jaccards"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_inter"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_found"] = []
        metrics_dict[algo][str(exploration_mult)]["fails"] = 0

        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, expl_mult: {exploration_mult}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width).to(device)
            reg = 1
            delay = 0
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            lr = 1e-2

            if algo == "UCB":
                agent = OptimNeuralTS(
                    net, nu=exploration_mult, lambda_=reg, style="ucb"
                )
            elif algo == "regTS":
                agent = OptimNeuralTS(net, nu=exploration_mult, lambda_=reg, style="ts")
            elif algo == "lenientTS":
                agent = LenientOptimNeuralTS(
                    [float("-inf"), 0],
                    net=net,
                    nu=exploration_mult,
                    lambda_=reg,
                )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            # Warmup
            for vec in vecs:
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad
            agent.train_dataset.set_(vecs, rewards)

            agent.net.eval()
            agent.train(max_n_steps, patience=max_n_steps, lds=False)

            # Playing
            for j in range(n_trials):
                agent.net.train()
                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                agent.net.eval()
                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                agent.U += best_member_grad * best_member_grad

                agent.train_dataset.add(a_t, r_t)

                agent.train(max_n_steps, patience=max_n_steps, lds=False)
            # Stop using mask in evaluation
            agent.net.eval()
            sol, _, _ = agent.find_solution_in_vecs(x, 0, n_sigmas=n_sigmas)
            sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol_idx)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(exploration_mult)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(exploration_mult)]["percent_inter"].append(
                percent_inter
            )
            metrics_dict[algo][str(exploration_mult)]["percent_found"].append(
                percent_found
            )

            if n_sol == 0:
                logging.info(f"Found no solution for run {i}")
                metrics_dict[algo][str(exploration_mult)]["fails"] += 1

                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_expl_{exploration_mult}_100_trials_seed_{i}",
                )

            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_basic.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: UCB, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: UCB, expl_mult: 1, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: UCB, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.18377088305489261, percent_inter: 1.0, percent_found: 0.18377088305489261
# INFO:root:at algo: UCB, expl_mult: 1, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.14081145584725538, percent_inter: 1.0, percent_found: 0.14081145584725538
# INFO:root:at algo: UCB, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.2529832935560859, percent_inter: 1.0, percent_found: 0.2529832935560859
# INFO:root:at algo: UCB, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: UCB, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: UCB, expl_mult: 1, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.15990453460620524, percent_inter: 1.0, percent_found: 0.15990453460620524
# INFO:root:at algo: UCB, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.3401826484018265, percent_inter: 0.8869047619047619, percent_found: 0.3556085918854415
# INFO:root:at algo: UCB, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: UCB, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: UCB, expl_mult: 1, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.1026252983293556, percent_inter: 1.0, percent_found: 0.1026252983293556
# INFO:root:at algo: UCB, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.26968973747016706, percent_inter: 1.0, percent_found: 0.26968973747016706
# INFO:root:at algo: UCB, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.06205250596658711, percent_inter: 1.0, percent_found: 0.06205250596658711
# INFO:root:at algo: UCB, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.0883054892601432, percent_inter: 1.0, percent_found: 0.0883054892601432
# INFO:root:at algo: UCB, expl_mult: 1, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 21
# INFO:root:jaccard: 0.19809069212410502, percent_inter: 1.0, percent_found: 0.19809069212410502
# INFO:root:at algo: UCB, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.050119331742243436, percent_inter: 1.0, percent_found: 0.050119331742243436
# INFO:root:at algo: UCB, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.21241050119331742, percent_inter: 1.0, percent_found: 0.21241050119331742
# INFO:root:at algo: UCB, expl_mult: 1, run: 24
# INFO:root:jaccard: 0.12649164677804295, percent_inter: 1.0, percent_found: 0.12649164677804295
# INFO:root:at algo: UCB, expl_mult: 1, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: UCB, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.15035799522673032, percent_inter: 1.0, percent_found: 0.15035799522673032
# INFO:root:at algo: UCB, expl_mult: 1, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: UCB, expl_mult: 1, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.23627684964200477, percent_inter: 1.0, percent_found: 0.23627684964200477
# INFO:root:at algo: UCB, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.2100238663484487, percent_inter: 1.0, percent_found: 0.2100238663484487
# INFO:root:at algo: UCB, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.016706443914081145, percent_inter: 1.0, percent_found: 0.016706443914081145
# INFO:root:at algo: UCB, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: UCB, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.20763723150357996, percent_inter: 1.0, percent_found: 0.20763723150357996
# INFO:root:at algo: UCB, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.24821002386634844, percent_inter: 1.0, percent_found: 0.24821002386634844
# INFO:root:at algo: UCB, expl_mult: 1, run: 39
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: UCB, expl_mult: 1, run: 40
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: UCB, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.10978520286396182, percent_inter: 1.0, percent_found: 0.10978520286396182
# INFO:root:at algo: UCB, expl_mult: 1, run: 42
# INFO:root:jaccard: 0.11455847255369929, percent_inter: 1.0, percent_found: 0.11455847255369929
# INFO:root:at algo: UCB, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.18377088305489261, percent_inter: 1.0, percent_found: 0.18377088305489261
# INFO:root:at algo: UCB, expl_mult: 1, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.271889400921659, percent_inter: 0.8872180451127819, percent_found: 0.28162291169451076
# INFO:root:at algo: UCB, expl_mult: 1, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.06443914081145585, percent_inter: 1.0, percent_found: 0.06443914081145585
# INFO:root:at algo: UCB, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.11217183770883055, percent_inter: 1.0, percent_found: 0.11217183770883055
# INFO:root:at algo: UCB, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.18377088305489261, percent_inter: 1.0, percent_found: 0.18377088305489261
# INFO:root:at algo: UCB, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: UCB, expl_mult: 10, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.14797136038186157, percent_inter: 1.0, percent_found: 0.14797136038186157
# INFO:root:at algo: UCB, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: UCB, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.2243436754176611, percent_inter: 1.0, percent_found: 0.2243436754176611
# INFO:root:at algo: UCB, expl_mult: 10, run: 5
# INFO:root:jaccard: 0.2458233890214797, percent_inter: 1.0, percent_found: 0.2458233890214797
# INFO:root:at algo: UCB, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: UCB, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.34844868735083534, percent_inter: 1.0, percent_found: 0.34844868735083534
# INFO:root:at algo: UCB, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.37708830548926014, percent_inter: 1.0, percent_found: 0.37708830548926014
# INFO:root:at algo: UCB, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.3788546255506608, percent_inter: 0.8309178743961353, percent_found: 0.4105011933174224
# INFO:root:at algo: UCB, expl_mult: 10, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.22580645161290322, percent_inter: 0.8672566371681416, percent_found: 0.23389021479713604
# INFO:root:at algo: UCB, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.40857787810383744, percent_inter: 0.8829268292682927, percent_found: 0.431980906921241
# INFO:root:at algo: UCB, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.3747016706443914, percent_inter: 1.0, percent_found: 0.3747016706443914
# INFO:root:at algo: UCB, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.27684964200477324, percent_inter: 1.0, percent_found: 0.27684964200477324
# INFO:root:at algo: UCB, expl_mult: 10, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: UCB, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.3747016706443914, percent_inter: 1.0, percent_found: 0.3747016706443914
# INFO:root:at algo: UCB, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.15274463007159905, percent_inter: 1.0, percent_found: 0.15274463007159905
# INFO:root:at algo: UCB, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: UCB, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: UCB, expl_mult: 10, run: 21
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: UCB, expl_mult: 10, run: 22
# INFO:root:jaccard: 0.10501193317422435, percent_inter: 1.0, percent_found: 0.10501193317422435
# INFO:root:at algo: UCB, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.32935560859188545, percent_inter: 1.0, percent_found: 0.32935560859188545
# INFO:root:at algo: UCB, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.0954653937947494, percent_inter: 1.0, percent_found: 0.0954653937947494
# INFO:root:at algo: UCB, expl_mult: 10, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.46539379474940334, percent_inter: 1.0, percent_found: 0.46539379474940334
# INFO:root:at algo: UCB, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.22664015904572565, percent_inter: 0.5757575757575758, percent_found: 0.2720763723150358
# INFO:root:at algo: UCB, expl_mult: 10, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: UCB, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: UCB, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.46904761904761905, percent_inter: 0.9949494949494949, percent_found: 0.4701670644391408
# INFO:root:at algo: UCB, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.3538812785388128, percent_inter: 0.8908045977011494, percent_found: 0.36992840095465396
# INFO:root:at algo: UCB, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.3295964125560538, percent_inter: 0.8448275862068966, percent_found: 0.35083532219570407
# INFO:root:at algo: UCB, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.16945107398568018, percent_inter: 1.0, percent_found: 0.16945107398568018
# INFO:root:at algo: UCB, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: UCB, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: UCB, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.27684964200477324, percent_inter: 1.0, percent_found: 0.27684964200477324
# INFO:root:at algo: UCB, expl_mult: 10, run: 39
# INFO:root:jaccard: 0.20763723150357996, percent_inter: 1.0, percent_found: 0.20763723150357996
# INFO:root:at algo: UCB, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: UCB, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: UCB, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.2100238663484487, percent_inter: 1.0, percent_found: 0.2100238663484487
# INFO:root:at algo: UCB, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: UCB, expl_mult: 10, run: 44
# INFO:root:jaccard: 0.045346062052505964, percent_inter: 1.0, percent_found: 0.045346062052505964
# INFO:root:at algo: UCB, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.36729857819905215, percent_inter: 0.9810126582278481, percent_found: 0.36992840095465396
# INFO:root:at algo: UCB, expl_mult: 10, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: UCB, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.11694510739856802, percent_inter: 1.0, percent_found: 0.11694510739856802
# INFO:root:at algo: UCB, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.26968973747016706, percent_inter: 1.0, percent_found: 0.26968973747016706
# INFO:root:at algo: regTS, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.25059665871121717, percent_inter: 1.0, percent_found: 0.25059665871121717
# INFO:root:at algo: regTS, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 1, run: 2
# INFO:root:jaccard: 0.24821002386634844, percent_inter: 1.0, percent_found: 0.24821002386634844
# INFO:root:at algo: regTS, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.24343675417661098, percent_inter: 1.0, percent_found: 0.24343675417661098
# INFO:root:at algo: regTS, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, expl_mult: 1, run: 5
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: regTS, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: regTS, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 1, run: 10
# INFO:root:jaccard: 0.23627684964200477, percent_inter: 1.0, percent_found: 0.23627684964200477
# INFO:root:at algo: regTS, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: regTS, expl_mult: 1, run: 15
# INFO:root:jaccard: 0.2744630071599045, percent_inter: 1.0, percent_found: 0.2744630071599045
# INFO:root:at algo: regTS, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: regTS, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: regTS, expl_mult: 1, run: 20
# INFO:root:jaccard: 0.32935560859188545, percent_inter: 1.0, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, expl_mult: 1, run: 21
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: regTS, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 1, run: 24
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, expl_mult: 1, run: 25
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 1, run: 28
# INFO:root:jaccard: 0.2744630071599045, percent_inter: 1.0, percent_found: 0.2744630071599045
# INFO:root:at algo: regTS, expl_mult: 1, run: 29
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, expl_mult: 1, run: 31
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, expl_mult: 1, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: regTS, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 1, run: 39
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, expl_mult: 1, run: 40
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: regTS, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 1, run: 42
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 1, run: 44
# INFO:root:jaccard: 0.3221957040572792, percent_inter: 1.0, percent_found: 0.3221957040572792
# INFO:root:at algo: regTS, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 1, run: 46
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 10, run: 1
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, expl_mult: 10, run: 5
# INFO:root:jaccard: 0.38424821002386633, percent_inter: 1.0, percent_found: 0.38424821002386633
# INFO:root:at algo: regTS, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: regTS, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, expl_mult: 10, run: 10
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, expl_mult: 10, run: 15
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: regTS, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.3794749403341289, percent_inter: 1.0, percent_found: 0.3794749403341289
# INFO:root:at algo: regTS, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: regTS, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: regTS, expl_mult: 10, run: 21
# INFO:root:jaccard: 0.2529832935560859, percent_inter: 1.0, percent_found: 0.2529832935560859
# INFO:root:at algo: regTS, expl_mult: 10, run: 22
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: regTS, expl_mult: 10, run: 25
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.3937947494033413, percent_inter: 1.0, percent_found: 0.3937947494033413
# INFO:root:at algo: regTS, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 10, run: 29
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 10, run: 39
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.35799522673031026, percent_inter: 1.0, percent_found: 0.35799522673031026
# INFO:root:at algo: regTS, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: regTS, expl_mult: 10, run: 44
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 10, run: 46
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 0
# /home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/torch/nn/init.py:46: UserWarning: Specified kernel cache directory could not be created! This disables kernel caching. Specified directory is /home/quo/.cache/torch/kernels. This warning will appear only once per process. (Triggered internally at  ../aten/src/ATen/native/cuda/jit_utils.cpp:860.)
#   tensor.erfinv_()
# INFO:root:jaccard: 0.15513126491646778, percent_inter: 1.0, percent_found: 0.15513126491646778
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.07398568019093078, percent_inter: 1.0, percent_found: 0.07398568019093078
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 2
# INFO:root:jaccard: 0.057279236276849645, percent_inter: 1.0, percent_found: 0.057279236276849645
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.21479713603818615, percent_inter: 1.0, percent_found: 0.21479713603818615
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.19331742243436753, percent_inter: 1.0, percent_found: 0.19331742243436753
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 5
# INFO:root:jaccard: 0.04295942720763723, percent_inter: 1.0, percent_found: 0.04295942720763723
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.1360381861575179, percent_inter: 1.0, percent_found: 0.1360381861575179
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.19809069212410502, percent_inter: 1.0, percent_found: 0.19809069212410502
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.16706443914081145, percent_inter: 1.0, percent_found: 0.16706443914081145
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 10
# INFO:root:jaccard: 0.06205250596658711, percent_inter: 1.0, percent_found: 0.06205250596658711
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.09307875894988067, percent_inter: 1.0, percent_found: 0.09307875894988067
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.2458233890214797, percent_inter: 1.0, percent_found: 0.2458233890214797
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.14797136038186157, percent_inter: 1.0, percent_found: 0.14797136038186157
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.26730310262529833, percent_inter: 1.0, percent_found: 0.26730310262529833
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.09069212410501193, percent_inter: 1.0, percent_found: 0.09069212410501193
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.13365155131264916, percent_inter: 1.0, percent_found: 0.13365155131264916
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.02386634844868735, percent_inter: 1.0, percent_found: 0.02386634844868735
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.26730310262529833, percent_inter: 1.0, percent_found: 0.26730310262529833
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 20
# INFO:root:jaccard: 0.050119331742243436, percent_inter: 1.0, percent_found: 0.050119331742243436
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.1766109785202864, percent_inter: 1.0, percent_found: 0.1766109785202864
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 24
# INFO:root:jaccard: 0.059665871121718374, percent_inter: 1.0, percent_found: 0.059665871121718374
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.2171837708830549, percent_inter: 1.0, percent_found: 0.2171837708830549
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 28
# INFO:root:jaccard: 0.06921241050119331, percent_inter: 1.0, percent_found: 0.06921241050119331
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 31
# INFO:root:jaccard: 0.1909307875894988, percent_inter: 1.0, percent_found: 0.1909307875894988
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.13365155131264916, percent_inter: 1.0, percent_found: 0.13365155131264916
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.13126491646778043, percent_inter: 1.0, percent_found: 0.13126491646778043
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.20763723150357996, percent_inter: 1.0, percent_found: 0.20763723150357996
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.15513126491646778, percent_inter: 1.0, percent_found: 0.15513126491646778
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.11933174224343675, percent_inter: 1.0, percent_found: 0.11933174224343675
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.18138424821002386, percent_inter: 1.0, percent_found: 0.18138424821002386
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 1
# INFO:root:jaccard: 0.07875894988066826, percent_inter: 1.0, percent_found: 0.07875894988066826
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.10501193317422435, percent_inter: 1.0, percent_found: 0.10501193317422435
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.23389021479713604, percent_inter: 1.0, percent_found: 0.23389021479713604
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.15513126491646778, percent_inter: 1.0, percent_found: 0.15513126491646778
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.17422434367541767, percent_inter: 1.0, percent_found: 0.17422434367541767
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.17899761336515513, percent_inter: 1.0, percent_found: 0.17899761336515513
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.2243436754176611, percent_inter: 1.0, percent_found: 0.2243436754176611
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 10
# INFO:root:jaccard: 0.11217183770883055, percent_inter: 1.0, percent_found: 0.11217183770883055
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.021479713603818614, percent_inter: 1.0, percent_found: 0.021479713603818614
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.26252983293556087, percent_inter: 1.0, percent_found: 0.26252983293556087
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.10501193317422435, percent_inter: 1.0, percent_found: 0.10501193317422435
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.18854415274463007, percent_inter: 1.0, percent_found: 0.18854415274463007
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.07159904534606205, percent_inter: 1.0, percent_found: 0.07159904534606205
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.19331742243436753, percent_inter: 1.0, percent_found: 0.19331742243436753
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.059665871121718374, percent_inter: 1.0, percent_found: 0.059665871121718374
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.2243436754176611, percent_inter: 1.0, percent_found: 0.2243436754176611
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.2243436754176611, percent_inter: 1.0, percent_found: 0.2243436754176611
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.2052505966587112, percent_inter: 1.0, percent_found: 0.2052505966587112
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.08591885441527446, percent_inter: 1.0, percent_found: 0.08591885441527446
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.10023866348448687, percent_inter: 1.0, percent_found: 0.10023866348448687
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.07398568019093078, percent_inter: 1.0, percent_found: 0.07398568019093078
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.11455847255369929, percent_inter: 1.0, percent_found: 0.11455847255369929
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.07398568019093078, percent_inter: 1.0, percent_found: 0.07398568019093078
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.20763723150357996, percent_inter: 1.0, percent_found: 0.20763723150357996
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.10023866348448687, percent_inter: 1.0, percent_found: 0.10023866348448687
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.21479713603818615, percent_inter: 1.0, percent_found: 0.21479713603818615

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for expl_mult in metrics_dict[algo].keys():
        logging.info(f'Expl mult: {expl_mult}')
        for metric in  metrics_dict[algo][expl_mult].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][expl_mult][metric])} +- {np.std(metrics_dict[algo][expl_mult][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][expl_mult][metric])}, {np.max(metrics_dict[algo][expl_mult][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: UCB
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.13921041473348642 +- 0.10708745144327263
# INFO:root:interval:  [0.0, 0.3401826484018265]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.735482456140351 +- 0.43650965056344243
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.13971360381861575 +- 0.10793418282933294
# INFO:root:interval:  [0.0, 0.3556085918854415]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 13.0 +- 0.0
# INFO:root:interval:  [13, 13]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.24197210301252048 +- 0.13053553699860174
# INFO:root:interval:  [0.0, 0.46904761904761905]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.8373690650735106 +- 0.3450751923360507
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.24496420047732695 +- 0.13260565878302782
# INFO:root:interval:  [0.0, 0.4701670644391408]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 7.0 +- 0.0
# INFO:root:interval:  [7, 7]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: regTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.2911694510739857 +- 0.04950412281609231
# INFO:root:interval:  [0.0, 0.360381861575179]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.98 +- 0.13999999999999999
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.2911694510739857 +- 0.04950412281609231
# INFO:root:interval:  [0.0, 0.360381861575179]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1, 1]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.3152267303102625 +- 0.028650912649601085
# INFO:root:interval:  [0.2529832935560859, 0.3937947494033413]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.3152267303102625 +- 0.028650912649601085
# INFO:root:interval:  [0.2529832935560859, 0.3937947494033413]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 0.0 +- 0.0
# INFO:root:interval:  [0, 0]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: lenientTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.11178997613365155 +- 0.09863169220584961
# INFO:root:interval:  [0.0, 0.31742243436754175]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.7 +- 0.458257569495584
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.11178997613365155 +- 0.09863169220584961
# INFO:root:interval:  [0.0, 0.31742243436754175]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 15.0 +- 0.0
# INFO:root:interval:  [15, 15]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.11937947494033413 +- 0.10264804099447165
# INFO:root:interval:  [0.0, 0.3412887828162291]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.7 +- 0.458257569495584
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.11937947494033413 +- 0.10264804099447165
# INFO:root:interval:  [0.0, 0.3412887828162291]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 15.0 +- 0.0
# INFO:root:interval:  [15, 15]
# INFO:root:============================================
# INFO:root:============================================

# %% [markdown]
# ## Test avec weight decay

# %%
metrics_dict = {}
algos = ["UCB", "regTS", "lenientTS"]
exploration_mults = [1, 10]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for exploration_mult in exploration_mults:
        metrics_dict[algo][str(exploration_mult)] = {}
        metrics_dict[algo][str(exploration_mult)]["jaccards"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_inter"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_found"] = []
        metrics_dict[algo][str(exploration_mult)]["fails"] = 0

        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, expl_mult: {exploration_mult}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width).to(device)
            reg = 1
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            lr = 1e-2

            if algo == "UCB":
                agent = OptimNeuralTS(
                    net, nu=exploration_mult, lambda_=reg, style="ucb"
                )
            elif algo == "regTS":
                agent = OptimNeuralTS(net, nu=exploration_mult, lambda_=reg, style="ts")
            elif algo == "lenientTS":
                agent = LenientOptimNeuralTS(
                    [float("-inf"), 0],
                    net=net,
                    nu=exploration_mult,
                    lambda_=reg,
                )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            agent.train_dataset.set_(vecs, rewards)

            # Warmup
            for vec in vecs:
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad

            agent.net.eval()
            agent.train(max_n_steps, patience=max_n_steps, lds=False, use_decay=True)
            # Playing
            for j in range(n_trials):
                agent.net.train()
                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                agent.net.eval()
                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                agent.U += best_member_grad * best_member_grad

                agent.train_dataset.add(a_t, r_t)

                agent.train(max_n_steps, patience=max_n_steps, lds=False, use_decay=True)

            # Stop using mask in evaluation
            sol, _, _ = agent.find_solution_in_vecs(x, 0, n_sigmas=n_sigmas)
            # sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol_idx)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(exploration_mult)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(exploration_mult)]["percent_inter"].append(
                percent_inter
            )
            metrics_dict[algo][str(exploration_mult)]["percent_found"].append(
                percent_found
            )

            if n_sol == 0:
                logging.info(f"Found no solution for run {i}")
                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_decay_expl_{exploration_mult}_100_trials_seed_{i}",
                )
                metrics_dict[algo][str(exploration_mult)]["fails"] += 1


            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_decay.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: UCB, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: UCB, expl_mult: 1, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: UCB, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.2171837708830549, percent_inter: 1.0, percent_found: 0.2171837708830549
# INFO:root:at algo: UCB, expl_mult: 1, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.1909307875894988, percent_inter: 1.0, percent_found: 0.1909307875894988
# INFO:root:at algo: UCB, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: UCB, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.23389021479713604, percent_inter: 1.0, percent_found: 0.23389021479713604
# INFO:root:at algo: UCB, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: UCB, expl_mult: 1, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.07637231503579953, percent_inter: 1.0, percent_found: 0.07637231503579953
# INFO:root:at algo: UCB, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.3029045643153527, percent_inter: 0.6985645933014354, percent_found: 0.34844868735083534
# INFO:root:at algo: UCB, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.15990453460620524, percent_inter: 1.0, percent_found: 0.15990453460620524
# INFO:root:at algo: UCB, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.2979214780600462, percent_inter: 0.9020979020979021, percent_found: 0.30787589498806683
# INFO:root:at algo: UCB, expl_mult: 1, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.2171837708830549, percent_inter: 1.0, percent_found: 0.2171837708830549
# INFO:root:at algo: UCB, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: UCB, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.05489260143198091, percent_inter: 1.0, percent_found: 0.05489260143198091
# INFO:root:at algo: UCB, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.11933174224343675, percent_inter: 1.0, percent_found: 0.11933174224343675
# INFO:root:at algo: UCB, expl_mult: 1, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 21
# INFO:root:jaccard: 0.225, percent_inter: 0.825, percent_found: 0.23627684964200477
# INFO:root:at algo: UCB, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.11217183770883055, percent_inter: 1.0, percent_found: 0.11217183770883055
# INFO:root:at algo: UCB, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.2331002331002331, percent_inter: 0.9090909090909091, percent_found: 0.2386634844868735
# INFO:root:at algo: UCB, expl_mult: 1, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.26014319809069214, percent_inter: 1.0, percent_found: 0.26014319809069214
# INFO:root:at algo: UCB, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.06682577565632458, percent_inter: 1.0, percent_found: 0.06682577565632458
# INFO:root:at algo: UCB, expl_mult: 1, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.35799522673031026, percent_inter: 1.0, percent_found: 0.35799522673031026
# INFO:root:at algo: UCB, expl_mult: 1, run: 31
# INFO:root:jaccard: 0.011933174224343675, percent_inter: 1.0, percent_found: 0.011933174224343675
# INFO:root:at algo: UCB, expl_mult: 1, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.1288782816229117, percent_inter: 1.0, percent_found: 0.1288782816229117
# INFO:root:at algo: UCB, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.20763723150357996, percent_inter: 1.0, percent_found: 0.20763723150357996
# INFO:root:at algo: UCB, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.09785202863961814, percent_inter: 1.0, percent_found: 0.09785202863961814
# INFO:root:at algo: UCB, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.2386634844868735, percent_inter: 1.0, percent_found: 0.2386634844868735
# INFO:root:at algo: UCB, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: UCB, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: UCB, expl_mult: 1, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.21241050119331742, percent_inter: 1.0, percent_found: 0.21241050119331742
# INFO:root:at algo: UCB, expl_mult: 1, run: 42
# INFO:root:jaccard: 0.15035799522673032, percent_inter: 1.0, percent_found: 0.15035799522673032
# INFO:root:at algo: UCB, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.081145584725537, percent_inter: 1.0, percent_found: 0.081145584725537
# INFO:root:at algo: UCB, expl_mult: 1, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.23048327137546468, percent_inter: 0.5102880658436214, percent_found: 0.29594272076372313
# INFO:root:at algo: UCB, expl_mult: 1, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.014319809069212411, percent_inter: 1.0, percent_found: 0.014319809069212411
# INFO:root:at algo: UCB, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: UCB, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.1575178997613365, percent_inter: 1.0, percent_found: 0.1575178997613365
# INFO:root:at algo: UCB, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: UCB, expl_mult: 10, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.15035799522673032, percent_inter: 1.0, percent_found: 0.15035799522673032
# INFO:root:at algo: UCB, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: UCB, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.3119047619047619, percent_inter: 0.9924242424242424, percent_found: 0.3126491646778043
# INFO:root:at algo: UCB, expl_mult: 10, run: 5
# INFO:root:jaccard: 0.24821002386634844, percent_inter: 1.0, percent_found: 0.24821002386634844
# INFO:root:at algo: UCB, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.2813186813186813, percent_inter: 0.7804878048780488, percent_found: 0.3054892601431981
# INFO:root:at algo: UCB, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.357630979498861, percent_inter: 0.8870056497175142, percent_found: 0.3747016706443914
# INFO:root:at algo: UCB, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.3972286374133949, percent_inter: 0.9247311827956989, percent_found: 0.4105011933174224
# INFO:root:at algo: UCB, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.35570469798657717, percent_inter: 0.8502673796791443, percent_found: 0.3794749403341289
# INFO:root:at algo: UCB, expl_mult: 10, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.18556701030927836, percent_inter: 0.5769230769230769, percent_found: 0.21479713603818615
# INFO:root:at algo: UCB, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.3705263157894737, percent_inter: 0.7586206896551724, percent_found: 0.4200477326968974
# INFO:root:at algo: UCB, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.38663484486873506, percent_inter: 1.0, percent_found: 0.38663484486873506
# INFO:root:at algo: UCB, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: UCB, expl_mult: 10, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.2553699284009546, percent_inter: 1.0, percent_found: 0.2553699284009546
# INFO:root:at algo: UCB, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.3221957040572792, percent_inter: 1.0, percent_found: 0.3221957040572792
# INFO:root:at algo: UCB, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.13126491646778043, percent_inter: 1.0, percent_found: 0.13126491646778043
# INFO:root:at algo: UCB, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: UCB, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.3127962085308057, percent_inter: 0.9777777777777777, percent_found: 0.315035799522673
# INFO:root:at algo: UCB, expl_mult: 10, run: 21
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: UCB, expl_mult: 10, run: 22
# INFO:root:jaccard: 0.14081145584725538, percent_inter: 1.0, percent_found: 0.14081145584725538
# INFO:root:at algo: UCB, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: UCB, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.10739856801909307, percent_inter: 1.0, percent_found: 0.10739856801909307
# INFO:root:at algo: UCB, expl_mult: 10, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.4186046511627907, percent_inter: 0.9424083769633508, percent_found: 0.4295942720763723
# INFO:root:at algo: UCB, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.20397111913357402, percent_inter: 0.45564516129032256, percent_found: 0.26968973747016706
# INFO:root:at algo: UCB, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.031026252983293555, percent_inter: 1.0, percent_found: 0.031026252983293555
# INFO:root:at algo: UCB, expl_mult: 10, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.3578199052132701, percent_inter: 0.9805194805194806, percent_found: 0.360381861575179
# INFO:root:at algo: UCB, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.34844868735083534, percent_inter: 1.0, percent_found: 0.34844868735083534
# INFO:root:at algo: UCB, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.4272930648769575, percent_inter: 0.8721461187214612, percent_found: 0.45584725536992843
# INFO:root:at algo: UCB, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.3047034764826176, percent_inter: 0.680365296803653, percent_found: 0.3556085918854415
# INFO:root:at algo: UCB, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.28629856850715746, percent_inter: 0.6666666666666666, percent_found: 0.3341288782816229
# INFO:root:at algo: UCB, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: UCB, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: UCB, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.36992840095465396, percent_inter: 1.0, percent_found: 0.36992840095465396
# INFO:root:at algo: UCB, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: UCB, expl_mult: 10, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.24343675417661098, percent_inter: 1.0, percent_found: 0.24343675417661098
# INFO:root:at algo: UCB, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.2895927601809955, percent_inter: 0.847682119205298, percent_found: 0.3054892601431981
# INFO:root:at algo: UCB, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.14797136038186157, percent_inter: 1.0, percent_found: 0.14797136038186157
# INFO:root:at algo: UCB, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: UCB, expl_mult: 10, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.21084337349397592, percent_inter: 0.5706521739130435, percent_found: 0.25059665871121717
# INFO:root:at algo: UCB, expl_mult: 10, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.25059665871121717, percent_inter: 1.0, percent_found: 0.25059665871121717
# INFO:root:at algo: UCB, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.10023866348448687, percent_inter: 1.0, percent_found: 0.10023866348448687
# INFO:root:at algo: UCB, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.21241050119331742, percent_inter: 1.0, percent_found: 0.21241050119331742
# INFO:root:at algo: regTS, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: regTS, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: regTS, expl_mult: 1, run: 2
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: regTS, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 1, run: 5
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 1, run: 10
# INFO:root:jaccard: 0.27684964200477324, percent_inter: 1.0, percent_found: 0.27684964200477324
# INFO:root:at algo: regTS, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 15
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.26252983293556087, percent_inter: 1.0, percent_found: 0.26252983293556087
# INFO:root:at algo: regTS, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.26252983293556087, percent_inter: 1.0, percent_found: 0.26252983293556087
# INFO:root:at algo: regTS, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 1, run: 20
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, expl_mult: 1, run: 21
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: regTS, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, expl_mult: 1, run: 24
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 1, run: 25
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.3794749403341289, percent_inter: 1.0, percent_found: 0.3794749403341289
# INFO:root:at algo: regTS, expl_mult: 1, run: 28
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 29
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: regTS, expl_mult: 1, run: 31
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, expl_mult: 1, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.27684964200477324, percent_inter: 1.0, percent_found: 0.27684964200477324
# INFO:root:at algo: regTS, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.36754176610978523, percent_inter: 1.0, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, expl_mult: 1, run: 39
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 40
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, expl_mult: 1, run: 42
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 1, run: 44
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, expl_mult: 1, run: 46
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.32935560859188545, percent_inter: 1.0, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 10, run: 1
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 5
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: regTS, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.35799522673031026, percent_inter: 1.0, percent_found: 0.35799522673031026
# INFO:root:at algo: regTS, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 10, run: 10
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.3723150357995227, percent_inter: 1.0, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.32935560859188545, percent_inter: 1.0, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, expl_mult: 10, run: 15
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.35799522673031026, percent_inter: 1.0, percent_found: 0.35799522673031026
# INFO:root:at algo: regTS, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.32935560859188545, percent_inter: 1.0, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.33890214797136037, percent_inter: 1.0, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, expl_mult: 10, run: 21
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: regTS, expl_mult: 10, run: 22
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.3818615751789976, percent_inter: 1.0, percent_found: 0.3818615751789976
# INFO:root:at algo: regTS, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 25
# INFO:root:jaccard: 0.36754176610978523, percent_inter: 1.0, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.3221957040572792, percent_inter: 1.0, percent_found: 0.3221957040572792
# INFO:root:at algo: regTS, expl_mult: 10, run: 29
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.36515513126491644, percent_inter: 1.0, percent_found: 0.36515513126491644
# INFO:root:at algo: regTS, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 10, run: 39
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.3914081145584726, percent_inter: 1.0, percent_found: 0.3914081145584726
# INFO:root:at algo: regTS, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, expl_mult: 10, run: 44
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 10, run: 46
# INFO:root:jaccard: 0.36754176610978523, percent_inter: 1.0, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: regTS, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 0
# /home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/torch/nn/init.py:46: UserWarning: Specified kernel cache directory could not be created! This disables kernel caching. Specified directory is /home/quo/.cache/torch/kernels. This warning will appear only once per process. (Triggered internally at  ../aten/src/ATen/native/cuda/jit_utils.cpp:860.)
#   tensor.erfinv_()
# INFO:root:jaccard: 0.14797136038186157, percent_inter: 1.0, percent_found: 0.14797136038186157
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.021479713603818614, percent_inter: 1.0, percent_found: 0.021479713603818614
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.13126491646778043, percent_inter: 1.0, percent_found: 0.13126491646778043
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.06682577565632458, percent_inter: 1.0, percent_found: 0.06682577565632458
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.162291169451074, percent_inter: 1.0, percent_found: 0.162291169451074
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.17899761336515513, percent_inter: 1.0, percent_found: 0.17899761336515513
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.1766109785202864, percent_inter: 1.0, percent_found: 0.1766109785202864
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 10
# INFO:root:jaccard: 0.12649164677804295, percent_inter: 1.0, percent_found: 0.12649164677804295
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 11
# INFO:root:Found no solution for run 11
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.24606299212598426, percent_inter: 0.5841121495327103, percent_found: 0.29832935560859186
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.17899761336515513, percent_inter: 1.0, percent_found: 0.17899761336515513
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.13842482100238662, percent_inter: 1.0, percent_found: 0.13842482100238662
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.18854415274463007, percent_inter: 1.0, percent_found: 0.18854415274463007
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.14081145584725538, percent_inter: 1.0, percent_found: 0.14081145584725538
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.15274463007159905, percent_inter: 1.0, percent_found: 0.15274463007159905
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 24
# INFO:root:jaccard: 0.03818615751789976, percent_inter: 1.0, percent_found: 0.03818615751789976
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 28
# INFO:root:jaccard: 0.1957040572792363, percent_inter: 1.0, percent_found: 0.1957040572792363
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.07637231503579953, percent_inter: 1.0, percent_found: 0.07637231503579953
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.09307875894988067, percent_inter: 1.0, percent_found: 0.09307875894988067
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.11217183770883055, percent_inter: 1.0, percent_found: 0.11217183770883055
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.16945107398568018, percent_inter: 1.0, percent_found: 0.16945107398568018
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.1909307875894988, percent_inter: 1.0, percent_found: 0.1909307875894988
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.10023866348448687, percent_inter: 1.0, percent_found: 0.10023866348448687
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.21241050119331742, percent_inter: 1.0, percent_found: 0.21241050119331742
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.17422434367541767, percent_inter: 1.0, percent_found: 0.17422434367541767
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.04295942720763723, percent_inter: 1.0, percent_found: 0.04295942720763723
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.081145584725537, percent_inter: 1.0, percent_found: 0.081145584725537
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.08353221957040573, percent_inter: 1.0, percent_found: 0.08353221957040573
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.01909307875894988, percent_inter: 1.0, percent_found: 0.01909307875894988
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.1909307875894988, percent_inter: 1.0, percent_found: 0.1909307875894988
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.14797136038186157, percent_inter: 1.0, percent_found: 0.14797136038186157
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.18615751789976134, percent_inter: 1.0, percent_found: 0.18615751789976134
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.1360381861575179, percent_inter: 1.0, percent_found: 0.1360381861575179
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.18377088305489261, percent_inter: 1.0, percent_found: 0.18377088305489261
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 10
# INFO:root:jaccard: 0.09069212410501193, percent_inter: 1.0, percent_found: 0.09069212410501193
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.021479713603818614, percent_inter: 1.0, percent_found: 0.021479713603818614
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.25, percent_inter: 0.5477178423236515, percent_found: 0.315035799522673
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.21241050119331742, percent_inter: 1.0, percent_found: 0.21241050119331742
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.08353221957040573, percent_inter: 1.0, percent_found: 0.08353221957040573
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.10501193317422435, percent_inter: 1.0, percent_found: 0.10501193317422435
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.06921241050119331, percent_inter: 1.0, percent_found: 0.06921241050119331
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.081145584725537, percent_inter: 1.0, percent_found: 0.081145584725537
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.031026252983293555, percent_inter: 1.0, percent_found: 0.031026252983293555
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 25
# INFO:root:jaccard: 0.00477326968973747, percent_inter: 1.0, percent_found: 0.00477326968973747
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.16706443914081145, percent_inter: 1.0, percent_found: 0.16706443914081145
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.06682577565632458, percent_inter: 1.0, percent_found: 0.06682577565632458
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.07637231503579953, percent_inter: 1.0, percent_found: 0.07637231503579953
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.2698412698412698, percent_inter: 0.8439716312056738, percent_found: 0.2840095465393795
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.1718377088305489, percent_inter: 1.0, percent_found: 0.1718377088305489
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.11694510739856802, percent_inter: 1.0, percent_found: 0.11694510739856802
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 41
# INFO:root:Found no solution for run 41
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.1431980906921241, percent_inter: 1.0, percent_found: 0.1431980906921241
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.15274463007159905, percent_inter: 1.0, percent_found: 0.15274463007159905
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.11694510739856802, percent_inter: 1.0, percent_found: 0.11694510739856802

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for expl_mult in metrics_dict[algo].keys():
        logging.info(f'Expl mult: {expl_mult}')
        for metric in  metrics_dict[algo][expl_mult].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][expl_mult][metric])} +- {np.std(metrics_dict[algo][expl_mult][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][expl_mult][metric])}, {np.max(metrics_dict[algo][expl_mult][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: UCB
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.13690990931411023 +- 0.11812992901556693
# INFO:root:interval:  [0.0, 0.35799522673031026]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.6769008294066774 +- 0.4507660516175904
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.13966587112171838 +- 0.1214581335071609
# INFO:root:interval:  [0.0, 0.35799522673031026]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 15.0 +- 0.0
# INFO:root:interval:  [15, 15]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.23384658542938086 +- 0.13304759723846238
# INFO:root:interval:  [0.0, 0.4272930648769575]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.775286463958679 +- 0.36164131476457956
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.24229116945107398 +- 0.1378584743863558
# INFO:root:interval:  [0.0, 0.45584725536992843]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 8.0 +- 0.0
# INFO:root:interval:  [8, 8]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: regTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.301145584725537 +- 0.050420032142634436
# INFO:root:interval:  [0.0, 0.3794749403341289]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.98 +- 0.13999999999999999
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.301145584725537 +- 0.050420032142634436
# INFO:root:interval:  [0.0, 0.3794749403341289]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1, 1]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.3340334128878282 +- 0.023413167605295108
# INFO:root:interval:  [0.2649164677804296, 0.3914081145584726]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.3340334128878282 +- 0.023413167605295108
# INFO:root:interval:  [0.2649164677804296, 0.3914081145584726]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 0.0 +- 0.0
# INFO:root:interval:  [0, 0]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: lenientTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.09203343168022851 +- 0.09260344252515275
# INFO:root:interval:  [0.0, 0.31742243436754175]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.5916822429906542 +- 0.4865550980045147
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.09307875894988067 +- 0.0946095286595144
# INFO:root:interval:  [0.0, 0.31742243436754175]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 20.0 +- 0.0
# INFO:root:interval:  [20, 20]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.09034909269992801 +- 0.09066954713509334
# INFO:root:interval:  [0.0, 0.27923627684964203]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.6278337894705865 +- 0.4754686023078665
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.09193317422434368 +- 0.09393673476524755
# INFO:root:interval:  [0.0, 0.315035799522673]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 18.0 +- 0.0
# INFO:root:interval:  [18, 18]
# INFO:root:============================================
# INFO:root:============================================

# %% [markdown]
# ## Test avec dropout plutot que bonus d'exploration

# %%
metrics_dict = {}
algos = ["regTS"]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for dropout_rate in [0.2, 0.5, 0.8]:
        metrics_dict[algo][str(dropout_rate)] = {}
        metrics_dict[algo][str(dropout_rate)]["jaccards"] = []
        metrics_dict[algo][str(dropout_rate)]["percent_inter"] = []
        metrics_dict[algo][str(dropout_rate)]["percent_found"] = []
        metrics_dict[algo][str(dropout_rate)]["fails"] = 0
        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, dropout: {dropout_rate}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width, dropout=dropout_rate).to(device)
            reg = 1
            sampletype = "f"
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            bern_p = 1 - dropout_rate
            p_vec = torch.tensor([bern_p] * width)

            agent = OptimNeuralTS(
                net, lambda_=reg, style="ts", sampletype=sampletype
            )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            agent.train_dataset.set_(vecs, rewards)

            # Warmup
            for vec in vecs:
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad

            agent.net.eval()
            agent.train(max_n_steps, patience=max_n_steps, lds=False)
            # Train
            for j in range(n_trials):
                agent.net.train()
                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                agent.net.eval()

                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                if best_member_grad is None:
                    break
                agent.U += best_member_grad * best_member_grad

                agent.train_dataset.add(a_t, r_t)
                agent.train(max_n_steps, patience=max_n_steps, lds=False)

            if best_member_grad is None:
                metrics_dict[algo][str(dropout_rate)]["fails"] += 1
                logging.info(
                    f"Encountered a fail in {algo} {dropout_rate} because of nans"
                )
                continue
            agent.net.eval()
            sol, _, _ = agent.find_solution_in_vecs(x, 0, n_sigmas=n_sigmas)
            sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol_idx)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(dropout_rate)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(dropout_rate)]["percent_inter"].append(percent_inter)
            metrics_dict[algo][str(dropout_rate)]["percent_found"].append(percent_found)

            if n_sol == 0:
                logging.info(f"Found no solution for run {i}")
                metrics_dict[algo][str(dropout_rate)]["fails"] += 1

                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_drop_{dropout_rate}_100_trials_seed_{i}.png",
                )
            agent.net.train()

            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_dropout.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: regTS, dropout: 0.2, run: 0
# INFO:root:jaccard: 0.31211498973305957, percent_inter: 0.6909090909090909, percent_found: 0.3627684964200477
# INFO:root:at algo: regTS, dropout: 0.2, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 3
# INFO:root:jaccard: 0.25675675675675674, percent_inter: 0.5732758620689655, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, dropout: 0.2, run: 4
# INFO:root:jaccard: 0.21957040572792363, percent_inter: 1.0, percent_found: 0.21957040572792363
# INFO:root:at algo: regTS, dropout: 0.2, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 6
# INFO:root:jaccard: 0.22950819672131148, percent_inter: 0.6187845303867403, percent_found: 0.26730310262529833
# INFO:root:at algo: regTS, dropout: 0.2, run: 7
# INFO:root:Found no solution for run 7
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 8
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, dropout: 0.2, run: 9
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, dropout: 0.2, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 11
# INFO:root:jaccard: 0.21749408983451538, percent_inter: 0.9583333333333334, percent_found: 0.21957040572792363
# INFO:root:at algo: regTS, dropout: 0.2, run: 12
# INFO:root:jaccard: 0.25512104283054005, percent_inter: 0.5372549019607843, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, dropout: 0.2, run: 13
# INFO:root:jaccard: 0.3094688221709007, percent_inter: 0.9054054054054054, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, dropout: 0.2, run: 14
# INFO:root:Found no solution for run 14
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 16
# INFO:root:jaccard: 0.23935091277890466, percent_inter: 0.6145833333333334, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, dropout: 0.2, run: 17
# INFO:root:jaccard: 0.3120728929384966, percent_inter: 0.8726114649681529, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, dropout: 0.2, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 19
# INFO:root:Found no solution for run 19
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 21
# INFO:root:jaccard: 0.2546816479400749, percent_inter: 0.5418326693227091, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, dropout: 0.2, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 23
# INFO:root:jaccard: 0.27699530516431925, percent_inter: 0.944, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, dropout: 0.2, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 26
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, dropout: 0.2, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 33
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, dropout: 0.2, run: 34
# INFO:root:jaccard: 0.26773455377574373, percent_inter: 0.8666666666666667, percent_found: 0.27923627684964203
# INFO:root:at algo: regTS, dropout: 0.2, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 36
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, dropout: 0.2, run: 37
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, dropout: 0.2, run: 38
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.2, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 41
# INFO:root:jaccard: 0.3723150357995227, percent_inter: 1.0, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, dropout: 0.2, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 45
# INFO:root:jaccard: 0.1957040572792363, percent_inter: 1.0, percent_found: 0.1957040572792363
# INFO:root:at algo: regTS, dropout: 0.2, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 47
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, dropout: 0.2, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 49
# INFO:root:Found no solution for run 49
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 0
# INFO:root:jaccard: 0.3384615384615385, percent_inter: 0.8105263157894737, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, dropout: 0.5, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 3
# INFO:root:Found no solution for run 3
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 4
# INFO:root:jaccard: 0.2762312633832976, percent_inter: 0.7288135593220338, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, dropout: 0.5, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 6
# INFO:root:jaccard: 0.2222222222222222, percent_inter: 0.4714828897338403, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, dropout: 0.5, run: 7
# INFO:root:jaccard: 0.28053435114503816, percent_inter: 0.5833333333333334, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, dropout: 0.5, run: 8
# INFO:root:jaccard: 0.3356009070294785, percent_inter: 0.8705882352941177, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, dropout: 0.5, run: 9
# INFO:root:jaccard: 0.37735849056603776, percent_inter: 0.9696969696969697, percent_found: 0.3818615751789976
# INFO:root:at algo: regTS, dropout: 0.5, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 11
# INFO:root:jaccard: 0.2918454935622318, percent_inter: 0.7431693989071039, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, dropout: 0.5, run: 12
# INFO:root:jaccard: 0.3216494845360825, percent_inter: 0.7027027027027027, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, dropout: 0.5, run: 13
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: regTS, dropout: 0.5, run: 14
# INFO:root:Found no solution for run 14
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 16
# INFO:root:jaccard: 0.22586520947176686, percent_inter: 0.4881889763779528, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, dropout: 0.5, run: 17
# INFO:root:jaccard: 0.3296943231441048, percent_inter: 0.7947368421052632, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, dropout: 0.5, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 19
# INFO:root:jaccard: 0.3915094339622642, percent_inter: 0.9707602339181286, percent_found: 0.39618138424821003
# INFO:root:at algo: regTS, dropout: 0.5, run: 20
# INFO:root:jaccard: 0.17746913580246915, percent_inter: 0.33430232558139533, percent_found: 0.2744630071599045
# INFO:root:at algo: regTS, dropout: 0.5, run: 21
# INFO:root:jaccard: 0.30387931034482757, percent_inter: 0.7580645161290323, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, dropout: 0.5, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 23
# INFO:root:Found no solution for run 23
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 26
# INFO:root:jaccard: 0.37360178970917224, percent_inter: 0.8564102564102564, percent_found: 0.39856801909307876
# INFO:root:at algo: regTS, dropout: 0.5, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 30
# INFO:root:jaccard: 0.23859649122807017, percent_inter: 0.4738675958188153, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, dropout: 0.5, run: 31
# INFO:root:jaccard: 0.3063063063063063, percent_inter: 0.84472049689441, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, dropout: 0.5, run: 32
# INFO:root:jaccard: 0.00477326968973747, percent_inter: 1.0, percent_found: 0.00477326968973747
# INFO:root:at algo: regTS, dropout: 0.5, run: 33
# INFO:root:jaccard: 0.3318777292576419, percent_inter: 0.7958115183246073, percent_found: 0.3627684964200477
# INFO:root:at algo: regTS, dropout: 0.5, run: 34
# INFO:root:jaccard: 0.3129251700680272, percent_inter: 0.8625, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, dropout: 0.5, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 36
# INFO:root:jaccard: 0.3318872017353579, percent_inter: 0.7846153846153846, percent_found: 0.36515513126491644
# INFO:root:at algo: regTS, dropout: 0.5, run: 37
# INFO:root:jaccard: 0.3237704918032787, percent_inter: 0.6960352422907489, percent_found: 0.37708830548926014
# INFO:root:at algo: regTS, dropout: 0.5, run: 38
# INFO:root:jaccard: 0.3289760348583878, percent_inter: 0.7905759162303665, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, dropout: 0.5, run: 39
# INFO:root:jaccard: 0.2424812030075188, percent_inter: 0.5330578512396694, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, dropout: 0.5, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 41
# INFO:root:jaccard: 0.011933174224343675, percent_inter: 1.0, percent_found: 0.011933174224343675
# INFO:root:at algo: regTS, dropout: 0.5, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 47
# INFO:root:jaccard: 0.3247863247863248, percent_inter: 0.7562189054726368, percent_found: 0.3627684964200477
# INFO:root:at algo: regTS, dropout: 0.5, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 49
# INFO:root:jaccard: 0.1895551257253385, percent_inter: 0.5, percent_found: 0.23389021479713604
# INFO:root:at algo: regTS, dropout: 0.8, run: 0
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.8, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 3
# INFO:root:Found no solution for run 3
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 4
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, dropout: 0.8, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 6
# INFO:root:jaccard: 0.3626609442060086, percent_inter: 0.7824074074074074, percent_found: 0.4033412887828162
# INFO:root:at algo: regTS, dropout: 0.8, run: 7
# INFO:root:Found no solution for run 7
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 8
# INFO:root:Found no solution for run 8
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 9
# INFO:root:Found no solution for run 9
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 10
# INFO:root:jaccard: 0.34278959810874704, percent_inter: 0.9731543624161074, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.8, run: 11
# INFO:root:jaccard: 0.34811529933481156, percent_inter: 0.8306878306878307, percent_found: 0.3747016706443914
# INFO:root:at algo: regTS, dropout: 0.8, run: 12
# INFO:root:Found no solution for run 12
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 14
# INFO:root:Found no solution for run 14
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 16
# INFO:root:jaccard: 0.016706443914081145, percent_inter: 1.0, percent_found: 0.016706443914081145
# INFO:root:at algo: regTS, dropout: 0.8, run: 17
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, dropout: 0.8, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 19
# INFO:root:Found no solution for run 19
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 21
# INFO:root:jaccard: 0.3752913752913753, percent_inter: 0.9415204678362573, percent_found: 0.38424821002386633
# INFO:root:at algo: regTS, dropout: 0.8, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 23
# INFO:root:jaccard: 0.3905191873589165, percent_inter: 0.8781725888324873, percent_found: 0.4128878281622912
# INFO:root:at algo: regTS, dropout: 0.8, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 25
# INFO:root:jaccard: 0.00954653937947494, percent_inter: 1.0, percent_found: 0.00954653937947494
# INFO:root:at algo: regTS, dropout: 0.8, run: 26
# INFO:root:jaccard: 0.347926267281106, percent_inter: 0.9096385542168675, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, dropout: 0.8, run: 27
# INFO:root:jaccard: 0.04295942720763723, percent_inter: 1.0, percent_found: 0.04295942720763723
# INFO:root:at algo: regTS, dropout: 0.8, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 33
# INFO:root:jaccard: 0.3665943600867679, percent_inter: 0.8009478672985783, percent_found: 0.4033412887828162
# INFO:root:at algo: regTS, dropout: 0.8, run: 34
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, dropout: 0.8, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 36
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.8, run: 37
# INFO:root:jaccard: 0.0954653937947494, percent_inter: 1.0, percent_found: 0.0954653937947494
# INFO:root:at algo: regTS, dropout: 0.8, run: 38
# INFO:root:jaccard: 0.007159904534606206, percent_inter: 1.0, percent_found: 0.007159904534606206
# INFO:root:at algo: regTS, dropout: 0.8, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 40
# INFO:root:jaccard: 0.4092920353982301, percent_inter: 0.8486238532110092, percent_found: 0.441527446300716
# INFO:root:at algo: regTS, dropout: 0.8, run: 41
# INFO:root:Found no solution for run 41
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 47
# INFO:root:jaccard: 0.162291169451074, percent_inter: 1.0, percent_found: 0.162291169451074
# INFO:root:at algo: regTS, dropout: 0.8, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 49
# INFO:root:Found no solution for run 49
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for dropout_rate in metrics_dict[algo].keys():
        logging.info(f'dropout: {dropout_rate}')
        for metric in  metrics_dict[algo][dropout_rate].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][dropout_rate][metric])} +- {np.std(metrics_dict[algo][dropout_rate][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][dropout_rate][metric])}, {np.max(metrics_dict[algo][dropout_rate][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: regTS
# INFO:root:dropout: 0.2
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.12750426583580418 +- 0.1475108084599289
# INFO:root:interval:  [0.0, 0.3723150357995227]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.3824731451671036 +- 0.4466857350069357
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.13503579952267303 +- 0.1553734771507952
# INFO:root:interval:  [0.0, 0.3723150357995227]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 28.0 +- 0.0
# INFO:root:interval:  [28, 28]
# INFO:root:============================================
# INFO:root:dropout: 0.5
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.149317356966918 +- 0.15366529028854237
# INFO:root:interval:  [0.0, 0.3915094339622642]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.4024035893237648 +- 0.3943906750149449
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.1690692124105012 +- 0.17083328830925287
# INFO:root:interval:  [0.0, 0.39856801909307876]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 23.0 +- 0.0
# INFO:root:interval:  [23, 23]
# INFO:root:============================================
# INFO:root:dropout: 0.8
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.0983864543723455 +- 0.1538277509036516
# INFO:root:interval:  [0.0, 0.4092920353982301]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.3593030586381309 +- 0.46132567142508946
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.10205250596658712 +- 0.16052141899516195
# INFO:root:interval:  [0.0, 0.441527446300716]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 31.0 +- 0.0
# INFO:root:interval:  [31, 31]
# INFO:root:============================================
# INFO:root:============================================

# %% [markdown]
# # TEST - WORKS BETTER THAN ABOVE: Keep dropout active all the time instead of turning it off during training

# %%
metrics_dict = {}
algos = ["regTS"]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for dropout_rate in [0.2, 0.5, 0.8]:
        metrics_dict[algo][str(dropout_rate)] = {}
        metrics_dict[algo][str(dropout_rate)]["jaccards"] = []
        metrics_dict[algo][str(dropout_rate)]["percent_inter"] = []
        metrics_dict[algo][str(dropout_rate)]["percent_found"] = []
        metrics_dict[algo][str(dropout_rate)]["fails"] = 0
        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, dropout: {dropout_rate}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width, dropout=dropout_rate).to(device)
            reg = 1
            sampletype = "f"
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            bern_p = 1 - dropout_rate
            p_vec = torch.tensor([bern_p] * width)

            agent = OptimNeuralTS(
                net, lambda_=reg, style="ts", sampletype=sampletype
            )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            agent.train_dataset.set_(vecs, rewards)

            # Warmup
            for vec in vecs:
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad

                # agent.net.eval()
            agent.train(max_n_steps, patience=max_n_steps, lds=False)
                # agent.net.train()

            # Train
            for j in range(n_trials):

                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                if best_member_grad is None:
                    break
                agent.U += best_member_grad * best_member_grad

                agent.train_dataset.add(a_t, r_t)


                # agent.net.eval()
                agent.train(max_n_steps, patience=max_n_steps, lds=False)
                # agent.net.train()

            if best_member_grad is None:
                metrics_dict[algo][str(dropout_rate)]["fails"] += 1
                logging.info(
                    f"Encountered a fail in {algo} {dropout_rate} because of nans"
                )
                continue
            agent.net.eval()
            sol, _, _ = agent.find_solution_in_vecs(x, 0, n_sigmas=n_sigmas)
            sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol_idx)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(dropout_rate)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(dropout_rate)]["percent_inter"].append(percent_inter)
            metrics_dict[algo][str(dropout_rate)]["percent_found"].append(percent_found)

            if n_sol == 0:
                logging.info(f"Found no solution for run {i}")
                metrics_dict[algo][str(dropout_rate)]["fails"] += 1

                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_drop_{dropout_rate}_100_trials_seed_{i}.png",
                )
            agent.net.train()

            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_dropout.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: regTS, dropout: 0.2, run: 0
# INFO:root:jaccard: 0.37708830548926014, percent_inter: 1.0, percent_found: 0.37708830548926014
# INFO:root:at algo: regTS, dropout: 0.2, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 3
# INFO:root:Found no solution for run 3
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 4
# INFO:root:jaccard: 0.317016317016317, percent_inter: 0.9315068493150684, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, dropout: 0.2, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 6
# INFO:root:jaccard: 0.26014319809069214, percent_inter: 1.0, percent_found: 0.26014319809069214
# INFO:root:at algo: regTS, dropout: 0.2, run: 7
# INFO:root:jaccard: 0.4146919431279621, percent_inter: 0.9831460674157303, percent_found: 0.41766109785202865
# INFO:root:at algo: regTS, dropout: 0.2, run: 8
# INFO:root:jaccard: 0.3675799086757991, percent_inter: 0.8944444444444445, percent_found: 0.38424821002386633
# INFO:root:at algo: regTS, dropout: 0.2, run: 9
# INFO:root:jaccard: 0.3118279569892473, percent_inter: 0.7591623036649214, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.2, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 11
# INFO:root:jaccard: 0.23627684964200477, percent_inter: 1.0, percent_found: 0.23627684964200477
# INFO:root:at algo: regTS, dropout: 0.2, run: 12
# INFO:root:jaccard: 0.2857142857142857, percent_inter: 0.5991902834008097, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, dropout: 0.2, run: 13
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, dropout: 0.2, run: 14
# INFO:root:Found no solution for run 14
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 15
# INFO:root:Found no solution for run 15
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 16
# INFO:root:jaccard: 0.22586520947176686, percent_inter: 0.4881889763779528, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, dropout: 0.2, run: 17
# INFO:root:jaccard: 0.35357917570498915, percent_inter: 0.7951219512195122, percent_found: 0.38902147971360385
# INFO:root:at algo: regTS, dropout: 0.2, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 19
# INFO:root:jaccard: 0.26968973747016706, percent_inter: 1.0, percent_found: 0.26968973747016706
# INFO:root:at algo: regTS, dropout: 0.2, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 23
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, dropout: 0.2, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 26
# INFO:root:jaccard: 0.32935560859188545, percent_inter: 1.0, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, dropout: 0.2, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 28
# INFO:root:jaccard: 0.29583333333333334, percent_inter: 0.6995073891625616, percent_found: 0.33890214797136037
# INFO:root:at algo: regTS, dropout: 0.2, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 31
# INFO:root:jaccard: 0.22587268993839835, percent_inter: 0.6179775280898876, percent_found: 0.26252983293556087
# INFO:root:at algo: regTS, dropout: 0.2, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 33
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: regTS, dropout: 0.2, run: 34
# INFO:root:jaccard: 0.25, percent_inter: 0.6505376344086021, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, dropout: 0.2, run: 35
# INFO:root:Found no solution for run 35
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 36
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, dropout: 0.2, run: 37
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.2, run: 38
# INFO:root:jaccard: 0.38424821002386633, percent_inter: 1.0, percent_found: 0.38424821002386633
# INFO:root:at algo: regTS, dropout: 0.2, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 41
# INFO:root:Found no solution for run 41
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 43
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, dropout: 0.2, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 45
# INFO:root:Found no solution for run 45
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 47
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, dropout: 0.2, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 49
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, dropout: 0.5, run: 0
# INFO:root:jaccard: 0.4004524886877828, percent_inter: 0.885, percent_found: 0.4224343675417661
# INFO:root:at algo: regTS, dropout: 0.5, run: 1
# INFO:root:jaccard: 0.014319809069212411, percent_inter: 1.0, percent_found: 0.014319809069212411
# INFO:root:at algo: regTS, dropout: 0.5, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 3
# INFO:root:Found no solution for run 3
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 4
# INFO:root:jaccard: 0.29958677685950413, percent_inter: 0.6904761904761905, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.5, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 6
# INFO:root:jaccard: 0.002386634844868735, percent_inter: 1.0, percent_found: 0.002386634844868735
# INFO:root:at algo: regTS, dropout: 0.5, run: 7
# INFO:root:jaccard: 0.39503386004514673, percent_inter: 0.8793969849246231, percent_found: 0.41766109785202865
# INFO:root:at algo: regTS, dropout: 0.5, run: 8
# INFO:root:jaccard: 0.37014314928425357, percent_inter: 0.7211155378486056, percent_found: 0.431980906921241
# INFO:root:at algo: regTS, dropout: 0.5, run: 9
# INFO:root:jaccard: 0.39953271028037385, percent_inter: 0.95, percent_found: 0.4081145584725537
# INFO:root:at algo: regTS, dropout: 0.5, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 11
# INFO:root:jaccard: 0.28402366863905326, percent_inter: 0.6206896551724138, percent_found: 0.3436754176610978
# INFO:root:at algo: regTS, dropout: 0.5, run: 12
# INFO:root:jaccard: 0.3431952662721893, percent_inter: 0.6641221374045801, percent_found: 0.4152744630071599
# INFO:root:at algo: regTS, dropout: 0.5, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 14
# INFO:root:Found no solution for run 14
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 15
# INFO:root:jaccard: 0.00477326968973747, percent_inter: 1.0, percent_found: 0.00477326968973747
# INFO:root:at algo: regTS, dropout: 0.5, run: 16
# INFO:root:jaccard: 0.22288261515601784, percent_inter: 0.3712871287128713, percent_found: 0.35799522673031026
# INFO:root:at algo: regTS, dropout: 0.5, run: 17
# INFO:root:jaccard: 0.3765432098765432, percent_inter: 0.732, percent_found: 0.43675417661097854
# INFO:root:at algo: regTS, dropout: 0.5, run: 18
# INFO:root:jaccard: 0.3251121076233184, percent_inter: 0.8430232558139535, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.5, run: 19
# INFO:root:jaccard: 0.3967136150234742, percent_inter: 0.9602272727272727, percent_found: 0.4033412887828162
# INFO:root:at algo: regTS, dropout: 0.5, run: 20
# INFO:root:jaccard: 0.007159904534606206, percent_inter: 1.0, percent_found: 0.007159904534606206
# INFO:root:at algo: regTS, dropout: 0.5, run: 21
# INFO:root:jaccard: 0.3858447488584475, percent_inter: 0.898936170212766, percent_found: 0.4033412887828162
# INFO:root:at algo: regTS, dropout: 0.5, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 23
# INFO:root:jaccard: 0.4124168514412417, percent_inter: 0.8532110091743119, percent_found: 0.4439140811455847
# INFO:root:at algo: regTS, dropout: 0.5, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 25
# INFO:root:jaccard: 0.002386634844868735, percent_inter: 1.0, percent_found: 0.002386634844868735
# INFO:root:at algo: regTS, dropout: 0.5, run: 26
# INFO:root:jaccard: 0.4126637554585153, percent_inter: 0.8289473684210527, percent_found: 0.4510739856801909
# INFO:root:at algo: regTS, dropout: 0.5, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 29
# INFO:root:jaccard: 0.04295942720763723, percent_inter: 1.0, percent_found: 0.04295942720763723
# INFO:root:at algo: regTS, dropout: 0.5, run: 30
# INFO:root:jaccard: 0.271513353115727, percent_inter: 0.4178082191780822, percent_found: 0.43675417661097854
# INFO:root:at algo: regTS, dropout: 0.5, run: 31
# INFO:root:jaccard: 0.4043478260869565, percent_inter: 0.8193832599118943, percent_found: 0.4439140811455847
# INFO:root:at algo: regTS, dropout: 0.5, run: 32
# INFO:root:jaccard: 0.04295942720763723, percent_inter: 1.0, percent_found: 0.04295942720763723
# INFO:root:at algo: regTS, dropout: 0.5, run: 33
# INFO:root:jaccard: 0.38530066815144765, percent_inter: 0.8522167487684729, percent_found: 0.4128878281622912
# INFO:root:at algo: regTS, dropout: 0.5, run: 34
# INFO:root:jaccard: 0.3123644251626898, percent_inter: 0.7741935483870968, percent_found: 0.3436754176610978
# INFO:root:at algo: regTS, dropout: 0.5, run: 35
# INFO:root:jaccard: 0.011933174224343675, percent_inter: 1.0, percent_found: 0.011933174224343675
# INFO:root:at algo: regTS, dropout: 0.5, run: 36
# INFO:root:jaccard: 0.24351585014409222, percent_inter: 0.38063063063063063, percent_found: 0.4033412887828162
# INFO:root:at algo: regTS, dropout: 0.5, run: 37
# INFO:root:jaccard: 0.3228200371057514, percent_inter: 0.5918367346938775, percent_found: 0.4152744630071599
# INFO:root:at algo: regTS, dropout: 0.5, run: 38
# INFO:root:jaccard: 0.4021978021978022, percent_inter: 0.8356164383561644, percent_found: 0.43675417661097854
# INFO:root:at algo: regTS, dropout: 0.5, run: 39
# INFO:root:jaccard: 0.20364741641337386, percent_inter: 0.35924932975871315, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, dropout: 0.5, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 41
# INFO:root:jaccard: 0.4423529411764706, percent_inter: 0.9690721649484536, percent_found: 0.4486873508353222
# INFO:root:at algo: regTS, dropout: 0.5, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 45
# INFO:root:jaccard: 0.22317596566523606, percent_inter: 0.3577981651376147, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, dropout: 0.5, run: 46
# INFO:root:jaccard: 0.07159904534606205, percent_inter: 1.0, percent_found: 0.07159904534606205
# INFO:root:at algo: regTS, dropout: 0.5, run: 47
# INFO:root:Found no solution for run 47
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 49
# INFO:root:jaccard: 0.3572938689217759, percent_inter: 0.757847533632287, percent_found: 0.4033412887828162
# INFO:root:at algo: regTS, dropout: 0.8, run: 0
# INFO:root:jaccard: 0.35564053537284895, percent_inter: 0.6413793103448275, percent_found: 0.4439140811455847
# INFO:root:at algo: regTS, dropout: 0.8, run: 1
# INFO:root:Found no solution for run 1
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 2
# INFO:root:jaccard: 0.19236641221374046, percent_inter: 0.34806629834254144, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, dropout: 0.8, run: 3
# INFO:root:jaccard: 0.21367521367521367, percent_inter: 0.3464203233256351, percent_found: 0.35799522673031026
# INFO:root:at algo: regTS, dropout: 0.8, run: 4
# INFO:root:Found no solution for run 4
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 5
# INFO:root:jaccard: 0.3265993265993266, percent_inter: 0.5257452574525745, percent_found: 0.4630071599045346
# INFO:root:at algo: regTS, dropout: 0.8, run: 6
# INFO:root:Found no solution for run 6
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 7
# INFO:root:Found no solution for run 7
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 8
# INFO:root:jaccard: 0.009242144177449169, percent_inter: 0.03937007874015748, percent_found: 0.011933174224343675
# INFO:root:at algo: regTS, dropout: 0.8, run: 9
# INFO:root:jaccard: 0.3608617594254937, percent_inter: 0.5929203539823009, percent_found: 0.4797136038186158
# INFO:root:at algo: regTS, dropout: 0.8, run: 10
# INFO:root:jaccard: 0.31285988483685223, percent_inter: 0.6150943396226415, percent_found: 0.38902147971360385
# INFO:root:at algo: regTS, dropout: 0.8, run: 11
# INFO:root:jaccard: 0.2395543175487465, percent_inter: 0.3651804670912951, percent_found: 0.4105011933174224
# INFO:root:at algo: regTS, dropout: 0.8, run: 12
# INFO:root:jaccard: 0.007159904534606206, percent_inter: 1.0, percent_found: 0.007159904534606206
# INFO:root:at algo: regTS, dropout: 0.8, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 14
# INFO:root:jaccard: 0.23665223665223664, percent_inter: 0.3744292237442922, percent_found: 0.3914081145584726
# INFO:root:at algo: regTS, dropout: 0.8, run: 15
# INFO:root:jaccard: 0.04295942720763723, percent_inter: 1.0, percent_found: 0.04295942720763723
# INFO:root:at algo: regTS, dropout: 0.8, run: 16
# INFO:root:jaccard: 0.3780487804878049, percent_inter: 0.7181467181467182, percent_found: 0.4439140811455847
# INFO:root:at algo: regTS, dropout: 0.8, run: 17
# INFO:root:Found no solution for run 17
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 18
# INFO:root:jaccard: 0.15990453460620524, percent_inter: 1.0, percent_found: 0.15990453460620524
# INFO:root:at algo: regTS, dropout: 0.8, run: 19
# INFO:root:jaccard: 0.42701525054466233, percent_inter: 0.8305084745762712, percent_found: 0.4677804295942721
# INFO:root:at algo: regTS, dropout: 0.8, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 22
# INFO:root:jaccard: 0.03341288782816229, percent_inter: 1.0, percent_found: 0.03341288782816229
# INFO:root:at algo: regTS, dropout: 0.8, run: 23
# INFO:root:jaccard: 0.028639618138424822, percent_inter: 1.0, percent_found: 0.028639618138424822
# INFO:root:at algo: regTS, dropout: 0.8, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 25
# INFO:root:Found no solution for run 25
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 26
# INFO:root:jaccard: 0.33879781420765026, percent_inter: 0.5886075949367089, percent_found: 0.4439140811455847
# INFO:root:at algo: regTS, dropout: 0.8, run: 27
# INFO:root:jaccard: 0.37901498929336186, percent_inter: 0.7866666666666666, percent_found: 0.4224343675417661
# INFO:root:at algo: regTS, dropout: 0.8, run: 28
# INFO:root:jaccard: 0.26734104046242774, percent_inter: 0.4039301310043668, percent_found: 0.441527446300716
# INFO:root:at algo: regTS, dropout: 0.8, run: 29
# INFO:root:Found no solution for run 29
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 30
# INFO:root:jaccard: 0.021479713603818614, percent_inter: 1.0, percent_found: 0.021479713603818614
# INFO:root:at algo: regTS, dropout: 0.8, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 32
# INFO:root:jaccard: 0.05250596658711217, percent_inter: 1.0, percent_found: 0.05250596658711217
# INFO:root:at algo: regTS, dropout: 0.8, run: 33
# INFO:root:jaccard: 0.40545808966861596, percent_inter: 0.6887417218543046, percent_found: 0.4964200477326969
# INFO:root:at algo: regTS, dropout: 0.8, run: 34
# INFO:root:jaccard: 0.3880597014925373, percent_inter: 0.64, percent_found: 0.4964200477326969
# INFO:root:at algo: regTS, dropout: 0.8, run: 35
# INFO:root:jaccard: 0.06921241050119331, percent_inter: 1.0, percent_found: 0.06921241050119331
# INFO:root:at algo: regTS, dropout: 0.8, run: 36
# INFO:root:jaccard: 0.19382022471910113, percent_inter: 0.32018561484918795, percent_found: 0.32935560859188545
# INFO:root:at algo: regTS, dropout: 0.8, run: 37
# INFO:root:jaccard: 0.3648393194706994, percent_inter: 0.636963696369637, percent_found: 0.4606205250596659
# INFO:root:at algo: regTS, dropout: 0.8, run: 38
# INFO:root:jaccard: 0.3118811881188119, percent_inter: 0.5026595744680851, percent_found: 0.4510739856801909
# INFO:root:at algo: regTS, dropout: 0.8, run: 39
# INFO:root:Found no solution for run 39
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 41
# INFO:root:jaccard: 0.2116991643454039, percent_inter: 0.3370288248337029, percent_found: 0.3627684964200477
# INFO:root:at algo: regTS, dropout: 0.8, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 43
# INFO:root:jaccard: 0.3687374749498998, percent_inter: 0.696969696969697, percent_found: 0.43914081145584727
# INFO:root:at algo: regTS, dropout: 0.8, run: 44
# INFO:root:jaccard: 0.007159904534606206, percent_inter: 1.0, percent_found: 0.007159904534606206
# INFO:root:at algo: regTS, dropout: 0.8, run: 45
# INFO:root:jaccard: 0.2773109243697479, percent_inter: 0.6984126984126984, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, dropout: 0.8, run: 46
# INFO:root:jaccard: 0.3684210526315789, percent_inter: 0.6059701492537314, percent_found: 0.48448687350835323
# INFO:root:at algo: regTS, dropout: 0.8, run: 47
# INFO:root:jaccard: 0.39856801909307876, percent_inter: 1.0, percent_found: 0.39856801909307876
# INFO:root:at algo: regTS, dropout: 0.8, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 49
# INFO:root:Found no solution for run 49
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for dropout_rate in metrics_dict[algo].keys():
        logging.info(f'dropout: {dropout_rate}')
        for metric in  metrics_dict[algo][dropout_rate].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][dropout_rate][metric])} +- {np.std(metrics_dict[algo][dropout_rate][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][dropout_rate][metric])}, {np.max(metrics_dict[algo][dropout_rate][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: regTS
# INFO:root:dropout: 0.2
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.1501720269006353 +- 0.16024916488459579
# INFO:root:interval:  [0.0, 0.4146919431279621]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.4283756685499898 +- 0.45955056769861136
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.15723150357995228 +- 0.16673451227207464
# INFO:root:interval:  [0.0, 0.41766109785202865]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 26.0 +- 0.0
# INFO:root:interval:  [26, 26]
# INFO:root:============================================
# INFO:root:dropout: 0.5
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.17586304609232314 +- 0.17498813780732267
# INFO:root:interval:  [0.0, 0.4423529411764706]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.5402817096858386 +- 0.4087067073454151
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.20529832935560857 +- 0.19950068394663723
# INFO:root:interval:  [0.0, 0.4510739856801909]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 16.0 +- 0.0
# INFO:root:interval:  [16, 16]
# INFO:root:============================================
# INFO:root:dropout: 0.8
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.15497798463798113 +- 0.16026967216221505
# INFO:root:interval:  [0.0, 0.42701525054466233]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.4460679442997608 +- 0.3851818368908455
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.2024821002386635 +- 0.20695157964407399
# INFO:root:interval:  [0.0, 0.4964200477326969]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 17.0 +- 0.0
# INFO:root:interval:  [17, 17]
# INFO:root:============================================
# INFO:root:============================================
