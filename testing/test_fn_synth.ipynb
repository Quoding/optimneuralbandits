# %%
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.functional import normalize
from math import sqrt
from detorch import DE, Policy, Strategy
from detorch.config import default_config, Config
from typing import Type
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('..')
sys.path.append('viz')
from optimneuralts import NetworkDropout, DENeuralTSDiag, LenientDENeuralTSDiag
import viz_config
import logging

logging.basicConfig(level=logging.INFO)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
config = Config(default_config)
bounds = [-2.5, 1.5]
theta = torch.Tensor([0, 3, -2, -4, 1, 1]).to(device)
d = 1

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Classes

# %%
class PullPolicy(Policy):
    def __init__(self, eval_fn):
        super().__init__()
        self.point = torch.FloatTensor(1).uniform_(*bounds).to(device)
        self.params = nn.Parameter(
            self.point, requires_grad=False
        )
        self.eval_fn = eval_fn
        self.ucb = None

    def evaluate(self):
        self.transform()
        ucb, activation_grad, _, _ = self.eval_fn(self.point)
        ucb = ucb.detach().item()
        self.activation_grad = activation_grad
        self.ucb = ucb
        # logging.info(self.point)
        # logging.info(ucb)
        return ucb

    def transform(self):
        self.point = torch.clip(self.params, *bounds).to(device)
        self.params = nn.Parameter(
            self.point, requires_grad=False
        )
        # return generate_feature_vector_from_point(self.point)


class DEConfig:
    n_step: int = 3
    population_size: int = 60
    differential_weight: float = 0.8
    crossover_probability: float = 0.9
    strategy: Strategy = Strategy.best1bin
    seed: int = "does not matter"

# %% [markdown]
# # Utility

# %%
def compute_jaccard(found_solution, true_solution):
    found_sol_list = found_solution.tolist()
    true_sol_list = true_solution.tolist()

    n_in_inter = 0

    for vec in found_sol_list:
        n_in_inter += vec in true_sol_list

    return n_in_inter / (len(found_solution) + len(true_solution) - n_in_inter), n_in_inter

def make_deterministic(seed):
    # PyTorch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

    # Numpy
    np.random.seed(seed)

    # Built-in Python
    random.seed(seed)

def project_point(point):
    return torch.tensor([1, point, point ** 2, point ** 3, point ** 4, point ** 5]).to(device)

def reward_fn(point, add_noise=True):
    noise = torch.normal(0, 1, (1,)).item()

    vec = project_point(point)
    value = theta @ vec.T
    
    return value + add_noise * noise


def gen_warmup_vecs_and_rewards(n_warmup):
    vecs = torch.tensor([])
    rewards = torch.tensor([])
    for i in range(n_warmup):
        point = torch.FloatTensor(1).uniform_(bounds[0], bounds[1]).to(device)
        reward = torch.tensor([reward_fn(point)])

        vecs = torch.cat((vecs, point.cpu()))
        rewards = torch.cat((rewards, reward))
    vecs = vecs.view((n_warmup, -1))
    rewards = rewards.view((n_warmup, -1))
    return vecs, rewards


def plot_estimate(agent, trial, fn=None, title=""):
    n_points = 1000
    x = np.linspace(-2.5, 1.5, n_points)
    x_vec = []
    y = []
    for x_point in x:
        y.append(reward_fn(float(x_point), add_noise=False).cpu().numpy())

    y_pred = []
    cbs = []
    ucbs = []
    x_tns = torch.from_numpy(x)
    x_tns = x_tns.view(n_points, 1).float()

    for point in x_tns:
        sample, _, activ, cb = agent.get_sample(point.to(device))
        y_pred.append(activ)
        cbs.append(3 * cb)
        ucbs.append(sample)

    y_pred = np.array(y_pred)
    cbs = np.array(cbs)

    point_played = agent.vec_history.squeeze(0).cpu().numpy()
    rewards_rec = agent.reward_history.squeeze(0).cpu().numpy()
    n_played = point_played.shape[0]

    # plt.ylim(-20, 10)
    # plt.ylim(-25, 10)
    plt.plot(x, y, color="tab:blue", label="Vraie fonction")
    plt.plot(x, y_pred, color="tab:orange", label="Estimation de la fonction")
    # plt.fill_between(x, y_pred, ucbs, color='tab:red', alpha=0.3)
    plt.fill_between(
        x, y_pred + cbs, y_pred - cbs, alpha=0.3, color="tab:orange", zorder=-1, label="Intervalle de confiance",
    )
    plt.plot(
        x,
        [0] * n_points,
        color="black",
        linestyle="dashed",
        label="Seuil bonne/mauvaise action",
    )
    plt.scatter(
        point_played[:n_played],
        rewards_rec[:n_played],
        color="black",
        alpha=0.5,
        label="Points joués précédemment",
    )
    plt.scatter(
        point_played[-1], rewards_rec[-1], color="green", label="Dernier point joué"
    )

    plt.title(title)
    
    plt.xlabel("$x$")
    plt.ylabel("$y$")


    plt.legend()
    if fn is None:
        filename = f"images/exp_poly/regTS_{n_trials}_trials_expl_{exploration_mult}_trial_{trial}.png"
    else:
        filename = f"images/exp_poly/{fn}.png"
    plt.savefig(filename)

    plt.clf()


def find_best_member(eval_fn, de_config, seed):
    de_config.seed = seed
    config = Config(default_config)

    @config("policy")
    class PolicyConfig:
        policy: Type[Policy] = PullPolicy
        eval_fn: object = agent.get_sample

    config("de")(de_config)

    de = DE(config)
    de.train()

    return de.population[de.current_best]

# %% [markdown]
# # Visualize 1 run

# %%
run = 42
make_deterministic(run)

n_trials = 500
width = 100
net = NetworkDropout(d, width).to(device)
reg = 1
dropout_rate = 0.1
exploration_mult = 1
delay = 0
reward_fn = reward_fn
de_config = DEConfig
de_policy = PullPolicy
style="ts"
sampletype="r"

agent = DENeuralTSDiag(net, nu=exploration_mult, lambda_=reg, style=style, sampletype=sampletype)
# agent = LenientDENeuralTSDiag(net, nu=exploration_mult, lambda_=reg, reward_sample_thresholds=[float('-inf'), 0])

# %%
vecs, rewards = gen_warmup_vecs_and_rewards(10)
vecs, rewards = vecs.to(device), rewards.to(device)

# %%
for i in range(len(rewards)):
    agent.vec_history = vecs[:i + 1]
    agent.reward_history = rewards[:i + 1]

    if sampletype == "f":
        # Mask for 1 vec
        eval_mask = (
            torch.distributions.Bernoulli(
                torch.full_like(example_vec, (1 - dropout_rate))
            ).sample()
            / (1 - dropout_rate)
        ).to(device)

        # Mask for multiple vecs
        training_mask = (
            torch.distributions.Bernoulli(
                torch.full_like(agent.vec_history, (1 - dropout_rate))
            ).sample()
            / (1 - dropout_rate)
        ).to(device)

        agent.net.set_mask(eval_mask)
    else:
        training_mask = None

    vec = vecs[i]
    activ, grad = agent.compute_activation_and_grad(vec)
    agent.U += grad * grad

    agent.net.set_mask(training_mask)
    
    agent.train(100)

# %%
plot_estimate(agent, 0,  f'{style}_expl_{exploration_mult}_{sampletype}_run{run}_trial_0')

# %% [markdown]
# ### Train 1 run

# %%
for i in range(n_trials):
    if sampletype == "f":
        eval_mask = (
            torch.distributions.Bernoulli(
                torch.full_like(example_vec, (1 - dropout_rate))
            ).sample()
            / (1 - dropout_rate)
        ).to(device)


        agent.net.set_mask(eval_mask)
    best_member = find_best_member(agent.get_sample, de_config, i)
    best_member_grad = best_member.activation_grad
    a_t = best_member.point.unsqueeze(0)
    r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

    logging.info(f"trial: {i}")

    agent.U += best_member_grad * best_member_grad

    agent.vec_history = torch.cat((agent.vec_history, a_t))
    agent.reward_history = torch.cat((agent.reward_history, r_t))

    if sampletype == "f":
        training_mask = (
            torch.distributions.Bernoulli(
                torch.full_like(agent.vec_history, (1 - dropout_rate))
            ).sample()
            / (1 - dropout_rate)
        ).to(device)

        agent.net.set_mask(training_mask)

    n_steps = 100
    agent.train(n_steps)
    if (i + 1) % 100 == 0:
        plot_estimate(
            agent,
            0,
            f"{style}_expl_{exploration_mult}_{sampletype}_run{run}_trial_{i+1}"
        )
# Out:
# INFO:root:trial: 0
# INFO:root:trial: 1
# INFO:root:trial: 2
# INFO:root:trial: 3
# INFO:root:trial: 4
# INFO:root:trial: 5
# INFO:root:trial: 6
# INFO:root:trial: 7
# INFO:root:trial: 8
# INFO:root:trial: 9
# INFO:root:trial: 10
# INFO:root:trial: 11
# INFO:root:trial: 12
# INFO:root:trial: 13
# INFO:root:trial: 14
# INFO:root:trial: 15
# INFO:root:trial: 16
# INFO:root:trial: 17
# INFO:root:trial: 18
# INFO:root:trial: 19
# INFO:root:trial: 20
# INFO:root:trial: 21
# INFO:root:trial: 22
# INFO:root:trial: 23
# INFO:root:trial: 24
# INFO:root:trial: 25
# INFO:root:trial: 26
# INFO:root:trial: 27
# INFO:root:trial: 28
# INFO:root:trial: 29
# INFO:root:trial: 30
# INFO:root:trial: 31
# INFO:root:trial: 32
# INFO:root:trial: 33
# INFO:root:trial: 34
# INFO:root:trial: 35
# INFO:root:trial: 36
# INFO:root:trial: 37
# INFO:root:trial: 38
# INFO:root:trial: 39
# INFO:root:trial: 40
# INFO:root:trial: 41
# INFO:root:trial: 42
# INFO:root:trial: 43
# INFO:root:trial: 44
# INFO:root:trial: 45
# INFO:root:trial: 46
# INFO:root:trial: 47
# INFO:root:trial: 48
# INFO:root:trial: 49
# INFO:root:trial: 50
# INFO:root:trial: 51
# INFO:root:trial: 52
# INFO:root:trial: 53
# INFO:root:trial: 54
# INFO:root:trial: 55
# INFO:root:trial: 56
# INFO:root:trial: 57
# INFO:root:trial: 58
# INFO:root:trial: 59
# INFO:root:trial: 60
# INFO:root:trial: 61
# INFO:root:trial: 62
# INFO:root:trial: 63
# INFO:root:trial: 64
# INFO:root:trial: 65
# INFO:root:trial: 66
# INFO:root:trial: 67
# INFO:root:trial: 68
# INFO:root:trial: 69
# INFO:root:trial: 70
# INFO:root:trial: 71
# INFO:root:trial: 72
# INFO:root:trial: 73
# INFO:root:trial: 74
# INFO:root:trial: 75
# INFO:root:trial: 76
# INFO:root:trial: 77
# INFO:root:trial: 78
# INFO:root:trial: 79
# INFO:root:trial: 80
# INFO:root:trial: 81
# INFO:root:trial: 82
# INFO:root:trial: 83
# INFO:root:trial: 84
# INFO:root:trial: 85
# INFO:root:trial: 86
# INFO:root:trial: 87
# INFO:root:trial: 88
# INFO:root:trial: 89
# INFO:root:trial: 90
# INFO:root:trial: 91
# INFO:root:trial: 92
# INFO:root:trial: 93
# INFO:root:trial: 94
# INFO:root:trial: 95
# INFO:root:trial: 96
# INFO:root:trial: 97
# INFO:root:trial: 98
# INFO:root:trial: 99
# INFO:root:trial: 100
# INFO:root:trial: 101
# INFO:root:trial: 102
# INFO:root:trial: 103
# INFO:root:trial: 104
# INFO:root:trial: 105
# INFO:root:trial: 106
# INFO:root:trial: 107
# INFO:root:trial: 108
# INFO:root:trial: 109
# INFO:root:trial: 110
# INFO:root:trial: 111
# INFO:root:trial: 112
# INFO:root:trial: 113
# INFO:root:trial: 114
# INFO:root:trial: 115
# INFO:root:trial: 116
# INFO:root:trial: 117
# INFO:root:trial: 118
# INFO:root:trial: 119
# INFO:root:trial: 120
# INFO:root:trial: 121
# INFO:root:trial: 122
# INFO:root:trial: 123
# INFO:root:trial: 124
# INFO:root:trial: 125
# INFO:root:trial: 126
# INFO:root:trial: 127
# INFO:root:trial: 128
# INFO:root:trial: 129
# INFO:root:trial: 130
# INFO:root:trial: 131
# INFO:root:trial: 132
# INFO:root:trial: 133
# INFO:root:trial: 134
# INFO:root:trial: 135
# INFO:root:trial: 136
# INFO:root:trial: 137
# INFO:root:trial: 138
# INFO:root:trial: 139
# INFO:root:trial: 140
# INFO:root:trial: 141
# INFO:root:trial: 142
# INFO:root:trial: 143
# INFO:root:trial: 144
# INFO:root:trial: 145
# INFO:root:trial: 146
# INFO:root:trial: 147
# INFO:root:trial: 148
# INFO:root:trial: 149
# INFO:root:trial: 150
# INFO:root:trial: 151
# INFO:root:trial: 152
# INFO:root:trial: 153
# INFO:root:trial: 154
# INFO:root:trial: 155
# INFO:root:trial: 156
# INFO:root:trial: 157
# INFO:root:trial: 158
# INFO:root:trial: 159
# INFO:root:trial: 160
# INFO:root:trial: 161
# INFO:root:trial: 162
# INFO:root:trial: 163
# INFO:root:trial: 164
# INFO:root:trial: 165
# INFO:root:trial: 166
# INFO:root:trial: 167
# INFO:root:trial: 168
# INFO:root:trial: 169
# INFO:root:trial: 170
# INFO:root:trial: 171
# INFO:root:trial: 172
# INFO:root:trial: 173
# INFO:root:trial: 174
# INFO:root:trial: 175
# INFO:root:trial: 176
# INFO:root:trial: 177
# INFO:root:trial: 178
# INFO:root:trial: 179
# INFO:root:trial: 180
# INFO:root:trial: 181
# INFO:root:trial: 182
# INFO:root:trial: 183
# INFO:root:trial: 184
# INFO:root:trial: 185
# INFO:root:trial: 186
# INFO:root:trial: 187
# INFO:root:trial: 188
# INFO:root:trial: 189
# INFO:root:trial: 190
# INFO:root:trial: 191
# INFO:root:trial: 192
# INFO:root:trial: 193
# INFO:root:trial: 194
# INFO:root:trial: 195
# INFO:root:trial: 196
# INFO:root:trial: 197
# INFO:root:trial: 198
# INFO:root:trial: 199
# INFO:root:trial: 200
# INFO:root:trial: 201
# INFO:root:trial: 202
# INFO:root:trial: 203
# INFO:root:trial: 204
# INFO:root:trial: 205
# INFO:root:trial: 206
# INFO:root:trial: 207
# INFO:root:trial: 208
# INFO:root:trial: 209
# INFO:root:trial: 210
# INFO:root:trial: 211
# INFO:root:trial: 212
# INFO:root:trial: 213
# INFO:root:trial: 214
# INFO:root:trial: 215
# INFO:root:trial: 216
# INFO:root:trial: 217
# INFO:root:trial: 218
# INFO:root:trial: 219
# INFO:root:trial: 220
# INFO:root:trial: 221
# INFO:root:trial: 222
# INFO:root:trial: 223
# INFO:root:trial: 224
# INFO:root:trial: 225
# INFO:root:trial: 226
# INFO:root:trial: 227
# INFO:root:trial: 228
# INFO:root:trial: 229
# INFO:root:trial: 230
# INFO:root:trial: 231
# INFO:root:trial: 232
# INFO:root:trial: 233
# INFO:root:trial: 234
# INFO:root:trial: 235
# INFO:root:trial: 236
# INFO:root:trial: 237
# INFO:root:trial: 238
# INFO:root:trial: 239
# INFO:root:trial: 240
# INFO:root:trial: 241
# INFO:root:trial: 242
# INFO:root:trial: 243
# INFO:root:trial: 244
# INFO:root:trial: 245
# INFO:root:trial: 246
# INFO:root:trial: 247
# INFO:root:trial: 248
# INFO:root:trial: 249
# INFO:root:trial: 250
# INFO:root:trial: 251
# INFO:root:trial: 252
# INFO:root:trial: 253
# INFO:root:trial: 254
# INFO:root:trial: 255
# INFO:root:trial: 256
# INFO:root:trial: 257
# INFO:root:trial: 258
# INFO:root:trial: 259
# INFO:root:trial: 260
# INFO:root:trial: 261
# INFO:root:trial: 262
# INFO:root:trial: 263
# INFO:root:trial: 264
# INFO:root:trial: 265
# INFO:root:trial: 266
# INFO:root:trial: 267
# INFO:root:trial: 268
# INFO:root:trial: 269
# INFO:root:trial: 270
# INFO:root:trial: 271
# INFO:root:trial: 272
# INFO:root:trial: 273
# INFO:root:trial: 274
# INFO:root:trial: 275
# INFO:root:trial: 276
# INFO:root:trial: 277
# INFO:root:trial: 278
# INFO:root:trial: 279
# INFO:root:trial: 280
# INFO:root:trial: 281
# INFO:root:trial: 282
# INFO:root:trial: 283
# INFO:root:trial: 284
# INFO:root:trial: 285
# INFO:root:trial: 286
# INFO:root:trial: 287
# INFO:root:trial: 288
# INFO:root:trial: 289
# INFO:root:trial: 290
# INFO:root:trial: 291
# INFO:root:trial: 292
# INFO:root:trial: 293
# INFO:root:trial: 294
# INFO:root:trial: 295
# INFO:root:trial: 296
# INFO:root:trial: 297
# INFO:root:trial: 298
# INFO:root:trial: 299
# INFO:root:trial: 300
# INFO:root:trial: 301
# INFO:root:trial: 302
# INFO:root:trial: 303
# INFO:root:trial: 304
# INFO:root:trial: 305
# INFO:root:trial: 306
# INFO:root:trial: 307
# INFO:root:trial: 308
# INFO:root:trial: 309
# INFO:root:trial: 310
# INFO:root:trial: 311
# INFO:root:trial: 312
# INFO:root:trial: 313
# INFO:root:trial: 314
# INFO:root:trial: 315
# INFO:root:trial: 316
# INFO:root:trial: 317
# INFO:root:trial: 318
# INFO:root:trial: 319
# INFO:root:trial: 320
# INFO:root:trial: 321
# INFO:root:trial: 322
# INFO:root:trial: 323
# INFO:root:trial: 324
# INFO:root:trial: 325
# INFO:root:trial: 326
# INFO:root:trial: 327
# INFO:root:trial: 328
# INFO:root:trial: 329
# INFO:root:trial: 330
# INFO:root:trial: 331
# INFO:root:trial: 332
# INFO:root:trial: 333
# INFO:root:trial: 334
# INFO:root:trial: 335
# INFO:root:trial: 336
# INFO:root:trial: 337
# INFO:root:trial: 338
# INFO:root:trial: 339
# INFO:root:trial: 340
# INFO:root:trial: 341
# INFO:root:trial: 342
# INFO:root:trial: 343
# INFO:root:trial: 344
# INFO:root:trial: 345
# INFO:root:trial: 346
# INFO:root:trial: 347
# INFO:root:trial: 348
# INFO:root:trial: 349
# INFO:root:trial: 350
# INFO:root:trial: 351
# INFO:root:trial: 352
# INFO:root:trial: 353
# INFO:root:trial: 354
# INFO:root:trial: 355
# INFO:root:trial: 356
# INFO:root:trial: 357
# INFO:root:trial: 358
# INFO:root:trial: 359
# INFO:root:trial: 360
# INFO:root:trial: 361
# INFO:root:trial: 362
# INFO:root:trial: 363
# INFO:root:trial: 364
# INFO:root:trial: 365
# INFO:root:trial: 366
# INFO:root:trial: 367
# INFO:root:trial: 368
# INFO:root:trial: 369
# INFO:root:trial: 370
# INFO:root:trial: 371
# INFO:root:trial: 372
# INFO:root:trial: 373
# INFO:root:trial: 374
# INFO:root:trial: 375
# INFO:root:trial: 376
# INFO:root:trial: 377
# INFO:root:trial: 378
# INFO:root:trial: 379
# INFO:root:trial: 380
# INFO:root:trial: 381
# INFO:root:trial: 382
# INFO:root:trial: 383
# INFO:root:trial: 384
# INFO:root:trial: 385
# INFO:root:trial: 386
# INFO:root:trial: 387
# INFO:root:trial: 388
# INFO:root:trial: 389
# INFO:root:trial: 390
# INFO:root:trial: 391
# INFO:root:trial: 392
# INFO:root:trial: 393
# INFO:root:trial: 394
# INFO:root:trial: 395
# INFO:root:trial: 396
# INFO:root:trial: 397
# INFO:root:trial: 398
# INFO:root:trial: 399
# INFO:root:trial: 400
# INFO:root:trial: 401
# INFO:root:trial: 402
# INFO:root:trial: 403
# INFO:root:trial: 404
# INFO:root:trial: 405
# INFO:root:trial: 406
# INFO:root:trial: 407
# INFO:root:trial: 408
# INFO:root:trial: 409
# INFO:root:trial: 410
# INFO:root:trial: 411
# INFO:root:trial: 412
# INFO:root:trial: 413
# INFO:root:trial: 414
# INFO:root:trial: 415
# INFO:root:trial: 416
# INFO:root:trial: 417
# INFO:root:trial: 418
# INFO:root:trial: 419
# INFO:root:trial: 420
# INFO:root:trial: 421
# INFO:root:trial: 422
# INFO:root:trial: 423
# INFO:root:trial: 424
# INFO:root:trial: 425
# INFO:root:trial: 426
# INFO:root:trial: 427
# INFO:root:trial: 428
# INFO:root:trial: 429
# INFO:root:trial: 430
# INFO:root:trial: 431
# INFO:root:trial: 432
# INFO:root:trial: 433
# INFO:root:trial: 434
# INFO:root:trial: 435
# INFO:root:trial: 436
# INFO:root:trial: 437
# INFO:root:trial: 438
# INFO:root:trial: 439
# INFO:root:trial: 440
# INFO:root:trial: 441
# INFO:root:trial: 442
# INFO:root:trial: 443
# INFO:root:trial: 444
# INFO:root:trial: 445
# INFO:root:trial: 446
# INFO:root:trial: 447
# INFO:root:trial: 448
# INFO:root:trial: 449
# INFO:root:trial: 450
# INFO:root:trial: 451
# INFO:root:trial: 452
# INFO:root:trial: 453
# INFO:root:trial: 454
# INFO:root:trial: 455
# INFO:root:trial: 456
# INFO:root:trial: 457
# INFO:root:trial: 458
# INFO:root:trial: 459
# INFO:root:trial: 460
# INFO:root:trial: 461
# INFO:root:trial: 462
# INFO:root:trial: 463
# INFO:root:trial: 464
# INFO:root:trial: 465
# INFO:root:trial: 466
# INFO:root:trial: 467
# INFO:root:trial: 468
# INFO:root:trial: 469
# INFO:root:trial: 470
# INFO:root:trial: 471
# INFO:root:trial: 472
# INFO:root:trial: 473
# INFO:root:trial: 474
# INFO:root:trial: 475
# INFO:root:trial: 476
# INFO:root:trial: 477
# INFO:root:trial: 478
# INFO:root:trial: 479
# INFO:root:trial: 480
# INFO:root:trial: 481
# INFO:root:trial: 482
# INFO:root:trial: 483
# INFO:root:trial: 484
# INFO:root:trial: 485
# INFO:root:trial: 486
# INFO:root:trial: 487
# INFO:root:trial: 488
# INFO:root:trial: 489
# INFO:root:trial: 490
# INFO:root:trial: 491
# INFO:root:trial: 492
# INFO:root:trial: 493
# INFO:root:trial: 494
# INFO:root:trial: 495
# INFO:root:trial: 496
# INFO:root:trial: 497
# INFO:root:trial: 498
# INFO:root:trial: 499

# %% [markdown]
# # Train all runs, for all algos and every exploration

# %%
x_arr = np.linspace(-2.5, 1.5, 1000)
x_arr = x_arr.reshape(1000, 1)
x = torch.from_numpy(x_arr).to(device).float()
y = []
for point in x:
    y.append(reward_fn(point, add_noise=False).cpu().numpy())

y = np.array(y)
true_sol = x[np.where(y >= 0)[0]].to(device).float()
n_true_sol = len(true_sol)
logging.info(n_true_sol)
# Out:
# INFO:root:419

# %%
metrics_dict = {}
algos = ["UCB", "regTS", "lenientTS"]
exploration_mults = [1, 10]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for exploration_mult in exploration_mults:
        metrics_dict[algo][str(exploration_mult)] = {}
        metrics_dict[algo][str(exploration_mult)]["jaccards"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_inter"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_found"] = []
        metrics_dict[algo][str(exploration_mult)]["fails"] = 0

        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, expl_mult: {exploration_mult}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width).to(device)
            reg = 1
            delay = 0
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            lr = 1e-2

            if algo == "UCB":
                agent = DENeuralTSDiag(
                    net, nu=exploration_mult, lambda_=reg, style="ucb"
                )
            elif algo == "regTS":
                agent = DENeuralTSDiag(net, nu=exploration_mult, lambda_=reg, style="ts")
            elif algo == "lenientTS":
                agent = LenientDENeuralTSDiag(
                    [float("-inf"), 0],
                    net=net,
                    nu=exploration_mult,
                    lambda_=reg,
                )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            # Warmup
            for j in range(len(rewards)):
                agent.vec_history = vecs[: j + 1]
                agent.reward_history = rewards[: j + 1]
                vec = vecs[j]
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad
                agent.train(max_n_steps)

            # Playing
            for j in range(n_trials):
                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                agent.U += best_member_grad * best_member_grad

                agent.vec_history = torch.cat((agent.vec_history, a_t))
                agent.reward_history = torch.cat((agent.reward_history, r_t))

                n_steps = max_n_steps
                agent.train(n_steps, lr)

            # Stop using mask in evaluation
            agent.net.set_mask(None)
            sol, _, _ = agent.find_solution_in_vecs(x, 0)
            sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(exploration_mult)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(exploration_mult)]["percent_inter"].append(
                percent_inter
            )
            metrics_dict[algo][str(exploration_mult)]["percent_found"].append(
                percent_found
            )

            if percent_found == 0:
                logging.info(f"Found no solution for run {i}")
                metrics_dict[algo][exploration_mult]["fails"] += 1

                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_expl_{exploration_mult}_100_trials_seed_{i}",
                )

            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_basic.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: UCB, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.23627684964200477, percent_inter: 1.0, percent_found: 0.23627684964200477
# INFO:root:at algo: UCB, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.16467780429594273, percent_inter: 1.0, percent_found: 0.16467780429594273
# INFO:root:at algo: UCB, expl_mult: 1, run: 2
# INFO:root:jaccard: 0.11217183770883055, percent_inter: 1.0, percent_found: 0.11217183770883055
# INFO:root:at algo: UCB, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.1575178997613365, percent_inter: 1.0, percent_found: 0.1575178997613365
# INFO:root:at algo: UCB, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: UCB, expl_mult: 1, run: 5
# INFO:root:jaccard: 0.11933174224343675, percent_inter: 1.0, percent_found: 0.11933174224343675
# INFO:root:at algo: UCB, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.14797136038186157, percent_inter: 1.0, percent_found: 0.14797136038186157
# INFO:root:at algo: UCB, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: UCB, expl_mult: 1, run: 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb Cell 15' in <cell line: 6>()
#      <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000015?line=56'>57</a> # Playing
#      <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000015?line=57'>58</a> for j in range(n_trials):
# ---> <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000015?line=58'>59</a>     best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
#      <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000015?line=59'>60</a>     best_member_grad = best_member.activation_grad
#      <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000015?line=60'>61</a>     a_t = best_member.point.unsqueeze(0)
#
# /home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb Cell 5' in find_best_member(eval_fn, de_config, seed)
#     <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000004?line=128'>129</a> config("de")(de_config)
#     <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000004?line=130'>131</a> de = DE(config)
# --> <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000004?line=131'>132</a> de.train()
#     <a href='vscode-notebook-cell:/home/quo/Documents/Maitrise/optimneuralbandits/testing/test_fn_synth.ipynb#ch0000004?line=133'>134</a> return de.population[de.current_best]
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py:224, in DE.train(self)
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=220'>221</a>     sys.stdout = f
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=222'>223</a> while self.gen < self.config.de.n_step and not self._stop:
# --> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=223'>224</a>     self.step()
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=225'>226</a> sys.stdout = sys.__stdout__
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py:23, in hook.<locals>.wrapped(*args, **kwargs)
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=20'>21</a> for hook in func.before_register:
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=21'>22</a>     hook(*args, **kwargs)
# ---> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=22'>23</a> ret = func(*args, **kwargs)
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=23'>24</a> for hook in func.after_register:
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=24'>25</a>     hook(*args, **kwargs, ret=ret)
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py:208, in DE.step(self)
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=205'>206</a> if isinstance(self.config.de.differential_weight, tuple):
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=206'>207</a>     self.differential_weight = self.rng.uniform(*self.config.de.differential_weight)
# --> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=207'>208</a> population = self.generate_candidates()
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=208'>209</a> rewards = self.eval_population(population)
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=209'>210</a> self.selection(population, rewards)
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py:23, in hook.<locals>.wrapped(*args, **kwargs)
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=20'>21</a> for hook in func.before_register:
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=21'>22</a>     hook(*args, **kwargs)
# ---> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=22'>23</a> ret = func(*args, **kwargs)
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=23'>24</a> for hook in func.after_register:
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=24'>25</a>     hook(*args, **kwargs, ret=ret)
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py:190, in DE.generate_candidates(self)
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=187'>188</a> for idx, policy in enumerate(population):
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=188'>189</a>     policy.load_state_dict(self.population[idx].state_dict())
# --> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=189'>190</a>     self.mutate(policy)
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=190'>191</a> return population
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py:23, in hook.<locals>.wrapped(*args, **kwargs)
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=20'>21</a> for hook in func.before_register:
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=21'>22</a>     hook(*args, **kwargs)
# ---> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=22'>23</a> ret = func(*args, **kwargs)
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=23'>24</a> for hook in func.after_register:
#      <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/utils.py?line=24'>25</a>     hook(*args, **kwargs, ret=ret)
#
# File ~/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py:166, in DE.mutate(self, policy)
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=162'>163</a> mutation = p0 + self.differential_weight * diff
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=164'>165</a> if self.config.de.strategy <= 7:
# --> <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=165'>166</a>     cross = torch.rand(policy_params.shape) <= self.crossover_probability
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=166'>167</a>     policy_params[cross] = mutation[cross]
#     <a href='file:///home/quo/Documents/Maitrise/venv/lib/python3.8/site-packages/detorch/de.py?line=167'>168</a> else:
#
# KeyboardInterrupt:

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for expl_mult in metrics_dict[algo].keys():
        logging.info(f'Expl mult: {expl_mult}')
        for metric in  metrics_dict[algo][expl_mult].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][expl_mult][metric])} +- {np.std(metrics_dict[algo][expl_mult][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][expl_mult][metric])}, {np.max(metrics_dict[algo][expl_mult][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: UCB
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.18525059665871121 +- 0.11353248798498058
# INFO:root:interval:  [0.0, 0.36754176610978523]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.82 +- 0.3841874542459709
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.18525059665871121 +- 0.11353248798498058
# INFO:root:interval:  [0.0, 0.36754176610978523]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.37937471444639664 +- 0.09073709865168775
# INFO:root:interval:  [0.0, 0.5]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.8672342264774983 +- 0.20855617067576102
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.4120286396181384 +- 0.10120092734928988
# INFO:root:interval:  [0.0, 0.5083532219570406]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: regTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.3153699284009546 +- 0.02911698423253367
# INFO:root:interval:  [0.26014319809069214, 0.3747016706443914]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.3153699284009546 +- 0.02911698423253367
# INFO:root:interval:  [0.26014319809069214, 0.3747016706443914]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.37078758949880664 +- 0.0462065326554416
# INFO:root:interval:  [0.26252983293556087, 0.5011933174224343]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.37078758949880664 +- 0.0462065326554416
# INFO:root:interval:  [0.26252983293556087, 0.5011933174224343]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: lenientTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.1471121718377088 +- 0.12583316696337246
# INFO:root:interval:  [0.0, 0.35083532219570407]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.64 +- 0.48
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.1471121718377088 +- 0.12583316696337246
# INFO:root:interval:  [0.0, 0.35083532219570407]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.16334128878281626 +- 0.11695500420837646
# INFO:root:interval:  [0.0, 0.34844868735083534]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.72 +- 0.44899888641287294
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.16334128878281626 +- 0.11695500420837646
# INFO:root:interval:  [0.0, 0.34844868735083534]
# INFO:root:============================================
# INFO:root:============================================

# %% [markdown]
# ## Test avec weight decay

# %%
metrics_dict = {}
algos = ["UCB", "regTS", "lenientTS"]
exploration_mults = [1, 10]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for exploration_mult in exploration_mults:
        metrics_dict[algo][str(exploration_mult)] = {}
        metrics_dict[algo][str(exploration_mult)]["jaccards"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_inter"] = []
        metrics_dict[algo][str(exploration_mult)]["percent_found"] = []
        metrics_dict[algo][str(exploration_mult)]["fails"] = 0

        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, expl_mult: {exploration_mult}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width).to(device)
            reg = 1
            delay = 0
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            lr = 1e-2

            if algo == "UCB":
                agent = DENeuralTSDiag(
                    net, nu=exploration_mult, lambda_=reg, style="ucb", decay=True
                )
            elif algo == "regTS":
                agent = DENeuralTSDiag(net, nu=exploration_mult, lambda_=reg, style="ts", decay=True)
            elif algo == "lenientTS":
                agent = LenientDENeuralTSDiag(
                    [float("-inf"), 0],
                    net=net,
                    nu=exploration_mult,
                    lambda_=reg,
                    decay=True
                )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            # Warmup
            for j in range(len(rewards)):
                agent.vec_history = vecs[: j + 1]
                agent.reward_history = rewards[: j + 1]
                vec = vecs[j]
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad
                agent.train(max_n_steps)

            # Playing
            for j in range(n_trials):
                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                agent.U += best_member_grad * best_member_grad

                agent.vec_history = torch.cat((agent.vec_history, a_t))
                agent.reward_history = torch.cat((agent.reward_history, r_t))

                n_steps = max_n_steps
                agent.train(n_steps, lr)

            # Stop using mask in evaluation
            agent.net.set_mask(None)
            sol, _, _ = agent.find_solution_in_vecs(x, 0)
            sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(exploration_mult)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(exploration_mult)]["percent_inter"].append(
                percent_inter
            )
            metrics_dict[algo][str(exploration_mult)]["percent_found"].append(
                percent_found
            )

            if percent_found == 0:
                logging.info(f"Found no solution for run {i}")
                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_decay_expl_{exploration_mult}_100_trials_seed_{i}",
                )
                metrics_dict[algo][exploration_mult]["fails"] += 1


            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_decay.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: UCB, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: UCB, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.23627684964200477, percent_inter: 1.0, percent_found: 0.23627684964200477
# INFO:root:at algo: UCB, expl_mult: 1, run: 2
# INFO:root:jaccard: 0.23653395784543327, percent_inter: 0.926605504587156, percent_found: 0.24105011933174225
# INFO:root:at algo: UCB, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.1575178997613365, percent_inter: 1.0, percent_found: 0.1575178997613365
# INFO:root:at algo: UCB, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: UCB, expl_mult: 1, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.162291169451074, percent_inter: 1.0, percent_found: 0.162291169451074
# INFO:root:at algo: UCB, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.2458233890214797, percent_inter: 1.0, percent_found: 0.2458233890214797
# INFO:root:at algo: UCB, expl_mult: 1, run: 8
# INFO:root:Found no solution for run 8
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.40046838407494145, percent_inter: 0.9553072625698324, percent_found: 0.4081145584725537
# INFO:root:at algo: UCB, expl_mult: 1, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: UCB, expl_mult: 1, run: 12
# INFO:root:Found no solution for run 12
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.11217183770883055, percent_inter: 1.0, percent_found: 0.11217183770883055
# INFO:root:at algo: UCB, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.2386634844868735, percent_inter: 1.0, percent_found: 0.2386634844868735
# INFO:root:at algo: UCB, expl_mult: 1, run: 15
# INFO:root:jaccard: 0.24105011933174225, percent_inter: 1.0, percent_found: 0.24105011933174225
# INFO:root:at algo: UCB, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.2835164835164835, percent_inter: 0.7818181818181819, percent_found: 0.30787589498806683
# INFO:root:at algo: UCB, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.41025641025641024, percent_inter: 0.946236559139785, percent_found: 0.4200477326968974
# INFO:root:at algo: UCB, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.35799522673031026, percent_inter: 1.0, percent_found: 0.35799522673031026
# INFO:root:at algo: UCB, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: UCB, expl_mult: 1, run: 20
# INFO:root:jaccard: 0.03818615751789976, percent_inter: 1.0, percent_found: 0.03818615751789976
# INFO:root:at algo: UCB, expl_mult: 1, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.3218390804597701, percent_inter: 0.6199261992619927, percent_found: 0.4009546539379475
# INFO:root:at algo: UCB, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.15035799522673032, percent_inter: 1.0, percent_found: 0.15035799522673032
# INFO:root:at algo: UCB, expl_mult: 1, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 25
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: UCB, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.2714285714285714, percent_inter: 0.991304347826087, percent_found: 0.2720763723150358
# INFO:root:at algo: UCB, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: UCB, expl_mult: 1, run: 28
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: UCB, expl_mult: 1, run: 29
# INFO:root:jaccard: 0.0954653937947494, percent_inter: 1.0, percent_found: 0.0954653937947494
# INFO:root:at algo: UCB, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.36801541425818884, percent_inter: 0.6563573883161512, percent_found: 0.45584725536992843
# INFO:root:at algo: UCB, expl_mult: 1, run: 31
# INFO:root:jaccard: 0.31213872832369943, percent_inter: 0.6183206106870229, percent_found: 0.38663484486873506
# INFO:root:at algo: UCB, expl_mult: 1, run: 32
# INFO:root:jaccard: 0.3433874709976798, percent_inter: 0.925, percent_found: 0.3532219570405728
# INFO:root:at algo: UCB, expl_mult: 1, run: 33
# INFO:root:Found no solution for run 33
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.1431980906921241, percent_inter: 1.0, percent_found: 0.1431980906921241
# INFO:root:at algo: UCB, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: UCB, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.1288782816229117, percent_inter: 1.0, percent_found: 0.1288782816229117
# INFO:root:at algo: UCB, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.12649164677804295, percent_inter: 1.0, percent_found: 0.12649164677804295
# INFO:root:at algo: UCB, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.14081145584725538, percent_inter: 1.0, percent_found: 0.14081145584725538
# INFO:root:at algo: UCB, expl_mult: 1, run: 39
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: UCB, expl_mult: 1, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: UCB, expl_mult: 1, run: 42
# INFO:root:jaccard: 0.2646370023419204, percent_inter: 0.9338842975206612, percent_found: 0.26968973747016706
# INFO:root:at algo: UCB, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.23107569721115537, percent_inter: 0.5829145728643216, percent_found: 0.27684964200477324
# INFO:root:at algo: UCB, expl_mult: 1, run: 44
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: UCB, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.24343675417661098, percent_inter: 1.0, percent_found: 0.24343675417661098
# INFO:root:at algo: UCB, expl_mult: 1, run: 46
# INFO:root:jaccard: 0.3558139534883721, percent_inter: 0.9329268292682927, percent_found: 0.36515513126491644
# INFO:root:at algo: UCB, expl_mult: 1, run: 47
# INFO:root:Found no solution for run 47
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.23627684964200477, percent_inter: 1.0, percent_found: 0.23627684964200477
# INFO:root:at algo: UCB, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.2386634844868735, percent_inter: 1.0, percent_found: 0.2386634844868735
# INFO:root:at algo: UCB, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.38715953307393, percent_inter: 0.6768707482993197, percent_found: 0.47494033412887826
# INFO:root:at algo: UCB, expl_mult: 10, run: 1
# INFO:root:jaccard: 0.28895612708018154, percent_inter: 0.44110854503464203, percent_found: 0.45584725536992843
# INFO:root:at algo: UCB, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.36041666666666666, percent_inter: 0.7393162393162394, percent_found: 0.4128878281622912
# INFO:root:at algo: UCB, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.4225941422594142, percent_inter: 0.7739463601532567, percent_found: 0.4821002386634845
# INFO:root:at algo: UCB, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.3225806451612903, percent_inter: 0.49875311720698257, percent_found: 0.477326968973747
# INFO:root:at algo: UCB, expl_mult: 10, run: 5
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: UCB, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.34498834498834496, percent_inter: 0.9367088607594937, percent_found: 0.3532219570405728
# INFO:root:at algo: UCB, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.36507936507936506, percent_inter: 0.5830985915492958, percent_found: 0.49403341288782815
# INFO:root:at algo: UCB, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: UCB, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.44646924829157175, percent_inter: 0.9074074074074074, percent_found: 0.4677804295942721
# INFO:root:at algo: UCB, expl_mult: 10, run: 10
# INFO:root:jaccard: 0.35084033613445376, percent_inter: 0.7455357142857143, percent_found: 0.39856801909307876
# INFO:root:at algo: UCB, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.43707093821510296, percent_inter: 0.9138755980861244, percent_found: 0.45584725536992843
# INFO:root:at algo: UCB, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: UCB, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.4152744630071599, percent_inter: 1.0, percent_found: 0.4152744630071599
# INFO:root:at algo: UCB, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.407158836689038, percent_inter: 0.8666666666666667, percent_found: 0.4343675417661098
# INFO:root:at algo: UCB, expl_mult: 10, run: 15
# INFO:root:jaccard: 0.42790697674418604, percent_inter: 0.9435897435897436, percent_found: 0.43914081145584727
# INFO:root:at algo: UCB, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.40038684719535783, percent_inter: 0.6786885245901639, percent_found: 0.49403341288782815
# INFO:root:at algo: UCB, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.4622222222222222, percent_inter: 0.8702928870292888, percent_found: 0.4964200477326969
# INFO:root:at algo: UCB, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.4269911504424779, percent_inter: 0.8539823008849557, percent_found: 0.4606205250596659
# INFO:root:at algo: UCB, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.44630071599045346, percent_inter: 1.0, percent_found: 0.44630071599045346
# INFO:root:at algo: UCB, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: UCB, expl_mult: 10, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: UCB, expl_mult: 10, run: 22
# INFO:root:jaccard: 0.3701067615658363, percent_inter: 0.5925925925925926, percent_found: 0.4964200477326969
# INFO:root:at algo: UCB, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.37708830548926014, percent_inter: 1.0, percent_found: 0.37708830548926014
# INFO:root:at algo: UCB, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.3799126637554585, percent_inter: 0.8169014084507042, percent_found: 0.4152744630071599
# INFO:root:at algo: UCB, expl_mult: 10, run: 25
# INFO:root:jaccard: 0.3385416666666667, percent_inter: 0.5539772727272727, percent_found: 0.46539379474940334
# INFO:root:at algo: UCB, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.3564154786150713, percent_inter: 0.708502024291498, percent_found: 0.41766109785202865
# INFO:root:at algo: UCB, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.4029535864978903, percent_inter: 0.7764227642276422, percent_found: 0.45584725536992843
# INFO:root:at algo: UCB, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.42424242424242425, percent_inter: 0.7342657342657343, percent_found: 0.5011933174224343
# INFO:root:at algo: UCB, expl_mult: 10, run: 29
# INFO:root:jaccard: 0.3422818791946309, percent_inter: 0.5354330708661418, percent_found: 0.48687350835322196
# INFO:root:at algo: UCB, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.45714285714285713, percent_inter: 0.9948186528497409, percent_found: 0.45823389021479716
# INFO:root:at algo: UCB, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.2886178861788618, percent_inter: 0.6604651162790698, percent_found: 0.33890214797136037
# INFO:root:at algo: UCB, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.3526405451448041, percent_inter: 0.552, percent_found: 0.49403341288782815
# INFO:root:at algo: UCB, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.39909297052154197, percent_inter: 0.8888888888888888, percent_found: 0.4200477326968974
# INFO:root:at algo: UCB, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.43237250554323725, percent_inter: 0.8590308370044053, percent_found: 0.46539379474940334
# INFO:root:at algo: UCB, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.40524193548387094, percent_inter: 0.7230215827338129, percent_found: 0.4797136038186158
# INFO:root:at algo: UCB, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.42482100238663484, percent_inter: 1.0, percent_found: 0.42482100238663484
# INFO:root:at algo: UCB, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.4161073825503356, percent_inter: 0.8691588785046729, percent_found: 0.4439140811455847
# INFO:root:at algo: UCB, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.33557046979865773, percent_inter: 0.8426966292134831, percent_found: 0.35799522673031026
# INFO:root:at algo: UCB, expl_mult: 10, run: 39
# INFO:root:jaccard: 0.3801980198019802, percent_inter: 0.6906474820143885, percent_found: 0.45823389021479716
# INFO:root:at algo: UCB, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.002386634844868735, percent_inter: 1.0, percent_found: 0.002386634844868735
# INFO:root:at algo: UCB, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.39856801909307876, percent_inter: 1.0, percent_found: 0.39856801909307876
# INFO:root:at algo: UCB, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.391304347826087, percent_inter: 0.8144796380090498, percent_found: 0.4295942720763723
# INFO:root:at algo: UCB, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.41920374707259955, percent_inter: 0.9572192513368984, percent_found: 0.42720763723150357
# INFO:root:at algo: UCB, expl_mult: 10, run: 44
# INFO:root:jaccard: 0.38846153846153847, percent_inter: 0.6666666666666666, percent_found: 0.4821002386634845
# INFO:root:at algo: UCB, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.45372460496614, percent_inter: 0.8933333333333333, percent_found: 0.4797136038186158
# INFO:root:at algo: UCB, expl_mult: 10, run: 46
# INFO:root:jaccard: 0.3162251655629139, percent_inter: 0.5079787234042553, percent_found: 0.45584725536992843
# INFO:root:at algo: UCB, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.27684964200477324, percent_inter: 1.0, percent_found: 0.27684964200477324
# INFO:root:at algo: UCB, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.3914656771799629, percent_inter: 0.6374622356495468, percent_found: 0.5035799522673031
# INFO:root:at algo: UCB, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.3146964856230032, percent_inter: 0.4876237623762376, percent_found: 0.4701670644391408
# INFO:root:at algo: regTS, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 2
# INFO:root:jaccard: 0.3054892601431981, percent_inter: 1.0, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, expl_mult: 1, run: 5
# INFO:root:jaccard: 0.3198090692124105, percent_inter: 1.0, percent_found: 0.3198090692124105
# INFO:root:at algo: regTS, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.3317422434367542, percent_inter: 1.0, percent_found: 0.3317422434367542
# INFO:root:at algo: regTS, expl_mult: 1, run: 8
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.3436754176610978, percent_inter: 1.0, percent_found: 0.3436754176610978
# INFO:root:at algo: regTS, expl_mult: 1, run: 10
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: regTS, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, expl_mult: 1, run: 12
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 1, run: 13
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, expl_mult: 1, run: 15
# INFO:root:jaccard: 0.36992840095465396, percent_inter: 1.0, percent_found: 0.36992840095465396
# INFO:root:at algo: regTS, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.35799522673031026, percent_inter: 1.0, percent_found: 0.35799522673031026
# INFO:root:at algo: regTS, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.4343675417661098, percent_inter: 1.0, percent_found: 0.4343675417661098
# INFO:root:at algo: regTS, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 1, run: 20
# INFO:root:jaccard: 0.30787589498806683, percent_inter: 1.0, percent_found: 0.30787589498806683
# INFO:root:at algo: regTS, expl_mult: 1, run: 21
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 1, run: 23
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 24
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, expl_mult: 1, run: 25
# INFO:root:jaccard: 0.36754176610978523, percent_inter: 1.0, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, expl_mult: 1, run: 28
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 1, run: 29
# INFO:root:jaccard: 0.31026252983293556, percent_inter: 1.0, percent_found: 0.31026252983293556
# INFO:root:at algo: regTS, expl_mult: 1, run: 30
# INFO:root:jaccard: 0.3269689737470167, percent_inter: 1.0, percent_found: 0.3269689737470167
# INFO:root:at algo: regTS, expl_mult: 1, run: 31
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, expl_mult: 1, run: 32
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, expl_mult: 1, run: 33
# INFO:root:jaccard: 0.23389021479713604, percent_inter: 1.0, percent_found: 0.23389021479713604
# INFO:root:at algo: regTS, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.36754176610978523, percent_inter: 1.0, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 1, run: 36
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, expl_mult: 1, run: 37
# INFO:root:jaccard: 0.324582338902148, percent_inter: 1.0, percent_found: 0.324582338902148
# INFO:root:at algo: regTS, expl_mult: 1, run: 38
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, expl_mult: 1, run: 39
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 1, run: 40
# INFO:root:jaccard: 0.2911694510739857, percent_inter: 1.0, percent_found: 0.2911694510739857
# INFO:root:at algo: regTS, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: regTS, expl_mult: 1, run: 42
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 43
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, expl_mult: 1, run: 44
# INFO:root:jaccard: 0.315035799522673, percent_inter: 1.0, percent_found: 0.315035799522673
# INFO:root:at algo: regTS, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.31742243436754175, percent_inter: 1.0, percent_found: 0.31742243436754175
# INFO:root:at algo: regTS, expl_mult: 1, run: 46
# INFO:root:jaccard: 0.3723150357995227, percent_inter: 1.0, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, expl_mult: 1, run: 47
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: regTS, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.3221957040572792, percent_inter: 1.0, percent_found: 0.3221957040572792
# INFO:root:at algo: regTS, expl_mult: 1, run: 49
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: regTS, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.4874141876430206, percent_inter: 0.922077922077922, percent_found: 0.5083532219570406
# INFO:root:at algo: regTS, expl_mult: 10, run: 1
# INFO:root:jaccard: 0.4224343675417661, percent_inter: 1.0, percent_found: 0.4224343675417661
# INFO:root:at algo: regTS, expl_mult: 10, run: 2
# INFO:root:jaccard: 0.43914081145584727, percent_inter: 1.0, percent_found: 0.43914081145584727
# INFO:root:at algo: regTS, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.3794749403341289, percent_inter: 1.0, percent_found: 0.3794749403341289
# INFO:root:at algo: regTS, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.4606205250596659, percent_inter: 1.0, percent_found: 0.4606205250596659
# INFO:root:at algo: regTS, expl_mult: 10, run: 5
# INFO:root:jaccard: 0.47494033412887826, percent_inter: 1.0, percent_found: 0.47494033412887826
# INFO:root:at algo: regTS, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.42482100238663484, percent_inter: 1.0, percent_found: 0.42482100238663484
# INFO:root:at algo: regTS, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.48448687350835323, percent_inter: 1.0, percent_found: 0.48448687350835323
# INFO:root:at algo: regTS, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.45584725536992843, percent_inter: 1.0, percent_found: 0.45584725536992843
# INFO:root:at algo: regTS, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.45823389021479716, percent_inter: 1.0, percent_found: 0.45823389021479716
# INFO:root:at algo: regTS, expl_mult: 10, run: 10
# INFO:root:jaccard: 0.4081145584725537, percent_inter: 1.0, percent_found: 0.4081145584725537
# INFO:root:at algo: regTS, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.47255369928400953, percent_inter: 1.0, percent_found: 0.47255369928400953
# INFO:root:at algo: regTS, expl_mult: 10, run: 12
# INFO:root:jaccard: 0.43914081145584727, percent_inter: 1.0, percent_found: 0.43914081145584727
# INFO:root:at algo: regTS, expl_mult: 10, run: 13
# INFO:root:jaccard: 0.3723150357995227, percent_inter: 1.0, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.47494033412887826, percent_inter: 1.0, percent_found: 0.47494033412887826
# INFO:root:at algo: regTS, expl_mult: 10, run: 15
# INFO:root:jaccard: 0.36515513126491644, percent_inter: 1.0, percent_found: 0.36515513126491644
# INFO:root:at algo: regTS, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.40572792362768495, percent_inter: 1.0, percent_found: 0.40572792362768495
# INFO:root:at algo: regTS, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.5083532219570406, percent_inter: 1.0, percent_found: 0.5083532219570406
# INFO:root:at algo: regTS, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.4821002386634845, percent_inter: 1.0, percent_found: 0.4821002386634845
# INFO:root:at algo: regTS, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.4916467780429594, percent_inter: 1.0, percent_found: 0.4916467780429594
# INFO:root:at algo: regTS, expl_mult: 10, run: 20
# INFO:root:jaccard: 0.4009546539379475, percent_inter: 1.0, percent_found: 0.4009546539379475
# INFO:root:at algo: regTS, expl_mult: 10, run: 21
# INFO:root:jaccard: 0.4486873508353222, percent_inter: 1.0, percent_found: 0.4486873508353222
# INFO:root:at algo: regTS, expl_mult: 10, run: 22
# INFO:root:jaccard: 0.4439140811455847, percent_inter: 1.0, percent_found: 0.4439140811455847
# INFO:root:at algo: regTS, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.38902147971360385, percent_inter: 1.0, percent_found: 0.38902147971360385
# INFO:root:at algo: regTS, expl_mult: 10, run: 24
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, expl_mult: 10, run: 25
# INFO:root:jaccard: 0.4642857142857143, percent_inter: 0.8776371308016878, percent_found: 0.4964200477326969
# INFO:root:at algo: regTS, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.5023696682464455, percent_inter: 0.986046511627907, percent_found: 0.5059665871121718
# INFO:root:at algo: regTS, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.4343675417661098, percent_inter: 1.0, percent_found: 0.4343675417661098
# INFO:root:at algo: regTS, expl_mult: 10, run: 28
# INFO:root:jaccard: 0.47255369928400953, percent_inter: 1.0, percent_found: 0.47255369928400953
# INFO:root:at algo: regTS, expl_mult: 10, run: 29
# INFO:root:jaccard: 0.36992840095465396, percent_inter: 1.0, percent_found: 0.36992840095465396
# INFO:root:at algo: regTS, expl_mult: 10, run: 30
# INFO:root:jaccard: 0.4152744630071599, percent_inter: 1.0, percent_found: 0.4152744630071599
# INFO:root:at algo: regTS, expl_mult: 10, run: 31
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.4892601431980907, percent_inter: 1.0, percent_found: 0.4892601431980907
# INFO:root:at algo: regTS, expl_mult: 10, run: 33
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.4606205250596659, percent_inter: 1.0, percent_found: 0.4606205250596659
# INFO:root:at algo: regTS, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.39856801909307876, percent_inter: 1.0, percent_found: 0.39856801909307876
# INFO:root:at algo: regTS, expl_mult: 10, run: 36
# INFO:root:jaccard: 0.48423423423423423, percent_inter: 0.8958333333333334, percent_found: 0.513126491646778
# INFO:root:at algo: regTS, expl_mult: 10, run: 37
# INFO:root:jaccard: 0.494199535962877, percent_inter: 0.9466666666666667, percent_found: 0.5083532219570406
# INFO:root:at algo: regTS, expl_mult: 10, run: 38
# INFO:root:jaccard: 0.41766109785202865, percent_inter: 1.0, percent_found: 0.41766109785202865
# INFO:root:at algo: regTS, expl_mult: 10, run: 39
# INFO:root:jaccard: 0.46539379474940334, percent_inter: 1.0, percent_found: 0.46539379474940334
# INFO:root:at algo: regTS, expl_mult: 10, run: 40
# INFO:root:jaccard: 0.47255369928400953, percent_inter: 1.0, percent_found: 0.47255369928400953
# INFO:root:at algo: regTS, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.360381861575179, percent_inter: 1.0, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, expl_mult: 10, run: 42
# INFO:root:jaccard: 0.4821002386634845, percent_inter: 1.0, percent_found: 0.4821002386634845
# INFO:root:at algo: regTS, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.4630071599045346, percent_inter: 1.0, percent_found: 0.4630071599045346
# INFO:root:at algo: regTS, expl_mult: 10, run: 44
# INFO:root:jaccard: 0.503562945368171, percent_inter: 0.9906542056074766, percent_found: 0.5059665871121718
# INFO:root:at algo: regTS, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.3723150357995227, percent_inter: 1.0, percent_found: 0.3723150357995227
# INFO:root:at algo: regTS, expl_mult: 10, run: 46
# INFO:root:jaccard: 0.4896073903002309, percent_inter: 0.9380530973451328, percent_found: 0.5059665871121718
# INFO:root:at algo: regTS, expl_mult: 10, run: 47
# INFO:root:jaccard: 0.441527446300716, percent_inter: 1.0, percent_found: 0.441527446300716
# INFO:root:at algo: regTS, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, expl_mult: 10, run: 49
# INFO:root:jaccard: 0.4033412887828162, percent_inter: 1.0, percent_found: 0.4033412887828162
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 0
# INFO:root:jaccard: 0.26968973747016706, percent_inter: 1.0, percent_found: 0.26968973747016706
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 1
# INFO:root:jaccard: 0.1766109785202864, percent_inter: 1.0, percent_found: 0.1766109785202864
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 3
# INFO:root:jaccard: 0.15990453460620524, percent_inter: 1.0, percent_found: 0.15990453460620524
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 4
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 6
# INFO:root:jaccard: 0.18854415274463007, percent_inter: 1.0, percent_found: 0.18854415274463007
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 7
# INFO:root:jaccard: 0.16945107398568018, percent_inter: 1.0, percent_found: 0.16945107398568018
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 8
# INFO:root:Found no solution for run 8
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 9
# INFO:root:jaccard: 0.31027253668763105, percent_inter: 0.7184466019417476, percent_found: 0.3532219570405728
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 11
# INFO:root:jaccard: 0.1575178997613365, percent_inter: 1.0, percent_found: 0.1575178997613365
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 12
# INFO:root:Found no solution for run 12
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 14
# INFO:root:jaccard: 0.2553699284009546, percent_inter: 1.0, percent_found: 0.2553699284009546
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 15
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 16
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 17
# INFO:root:jaccard: 0.23389021479713604, percent_inter: 1.0, percent_found: 0.23389021479713604
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 18
# INFO:root:jaccard: 0.26373626373626374, percent_inter: 0.5313653136531366, percent_found: 0.3436754176610978
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 19
# INFO:root:jaccard: 0.11694510739856802, percent_inter: 1.0, percent_found: 0.11694510739856802
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 22
# INFO:root:jaccard: 0.28239845261121854, percent_inter: 0.5983606557377049, percent_found: 0.34844868735083534
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 23
# INFO:root:Found no solution for run 23
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 25
# INFO:root:jaccard: 0.2315035799522673, percent_inter: 1.0, percent_found: 0.2315035799522673
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 26
# INFO:root:jaccard: 0.20286396181384247, percent_inter: 1.0, percent_found: 0.20286396181384247
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 27
# INFO:root:jaccard: 0.18615751789976134, percent_inter: 1.0, percent_found: 0.18615751789976134
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 29
# INFO:root:jaccard: 0.20286396181384247, percent_inter: 1.0, percent_found: 0.20286396181384247
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 32
# INFO:root:jaccard: 0.16706443914081145, percent_inter: 1.0, percent_found: 0.16706443914081145
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 33
# INFO:root:Found no solution for run 33
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 34
# INFO:root:jaccard: 0.20047732696897375, percent_inter: 1.0, percent_found: 0.20047732696897375
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 35
# INFO:root:jaccard: 0.3126491646778043, percent_inter: 1.0, percent_found: 0.3126491646778043
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 36
# INFO:root:Found no solution for run 36
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 37
# INFO:root:Found no solution for run 37
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 38
# INFO:root:Found no solution for run 38
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 39
# INFO:root:jaccard: 0.1575178997613365, percent_inter: 1.0, percent_found: 0.1575178997613365
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 41
# INFO:root:jaccard: 0.27684964200477324, percent_inter: 1.0, percent_found: 0.27684964200477324
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 45
# INFO:root:jaccard: 0.27923627684964203, percent_inter: 1.0, percent_found: 0.27923627684964203
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 46
# INFO:root:jaccard: 0.1909307875894988, percent_inter: 1.0, percent_found: 0.1909307875894988
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 47
# INFO:root:Found no solution for run 47
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 48
# INFO:root:jaccard: 0.2553699284009546, percent_inter: 1.0, percent_found: 0.2553699284009546
# INFO:root:at algo: lenientTS, expl_mult: 1, run: 49
# INFO:root:Found no solution for run 49
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 0
# INFO:root:jaccard: 0.18377088305489261, percent_inter: 1.0, percent_found: 0.18377088305489261
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 1
# INFO:root:jaccard: 0.19331742243436753, percent_inter: 1.0, percent_found: 0.19331742243436753
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 2
# INFO:root:Found no solution for run 2
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 3
# INFO:root:jaccard: 0.16945107398568018, percent_inter: 1.0, percent_found: 0.16945107398568018
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 4
# INFO:root:jaccard: 0.2458233890214797, percent_inter: 1.0, percent_found: 0.2458233890214797
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 6
# INFO:root:jaccard: 0.045346062052505964, percent_inter: 1.0, percent_found: 0.045346062052505964
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 7
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 8
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 9
# INFO:root:jaccard: 0.32489451476793246, percent_inter: 0.7368421052631579, percent_found: 0.36754176610978523
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 11
# INFO:root:jaccard: 0.2577565632458234, percent_inter: 1.0, percent_found: 0.2577565632458234
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 12
# INFO:root:Found no solution for run 12
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 14
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 15
# INFO:root:jaccard: 0.2171837708830549, percent_inter: 1.0, percent_found: 0.2171837708830549
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 16
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 17
# INFO:root:jaccard: 0.2649164677804296, percent_inter: 1.0, percent_found: 0.2649164677804296
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 18
# INFO:root:jaccard: 0.27205882352941174, percent_inter: 0.5421245421245421, percent_found: 0.3532219570405728
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 19
# INFO:root:jaccard: 0.16467780429594273, percent_inter: 1.0, percent_found: 0.16467780429594273
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 20
# INFO:root:Found no solution for run 20
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 22
# INFO:root:Found no solution for run 22
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 23
# INFO:root:jaccard: 0.1026252983293556, percent_inter: 1.0, percent_found: 0.1026252983293556
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 25
# INFO:root:jaccard: 0.10023866348448687, percent_inter: 1.0, percent_found: 0.10023866348448687
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 26
# INFO:root:jaccard: 0.2243436754176611, percent_inter: 1.0, percent_found: 0.2243436754176611
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 27
# INFO:root:jaccard: 0.15513126491646778, percent_inter: 1.0, percent_found: 0.15513126491646778
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 28
# INFO:root:Found no solution for run 28
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 29
# INFO:root:jaccard: 0.1718377088305489, percent_inter: 1.0, percent_found: 0.1718377088305489
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 32
# INFO:root:jaccard: 0.11933174224343675, percent_inter: 1.0, percent_found: 0.11933174224343675
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 33
# INFO:root:Found no solution for run 33
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 34
# INFO:root:jaccard: 0.18138424821002386, percent_inter: 1.0, percent_found: 0.18138424821002386
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 35
# INFO:root:jaccard: 0.1718377088305489, percent_inter: 1.0, percent_found: 0.1718377088305489
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 36
# INFO:root:Found no solution for run 36
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 37
# INFO:root:Found no solution for run 37
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 38
# INFO:root:Found no solution for run 38
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 39
# INFO:root:jaccard: 0.22911694510739858, percent_inter: 1.0, percent_found: 0.22911694510739858
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 41
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 42
# INFO:root:Found no solution for run 42
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 43
# INFO:root:jaccard: 0.0883054892601432, percent_inter: 1.0, percent_found: 0.0883054892601432
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 44
# INFO:root:Found no solution for run 44
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 45
# INFO:root:jaccard: 0.2052505966587112, percent_inter: 1.0, percent_found: 0.2052505966587112
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 46
# INFO:root:Found no solution for run 46
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 47
# INFO:root:Found no solution for run 47
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 48
# INFO:root:jaccard: 0.10978520286396182, percent_inter: 1.0, percent_found: 0.10978520286396182
# INFO:root:at algo: lenientTS, expl_mult: 10, run: 49
# INFO:root:Found no solution for run 49
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for expl_mult in metrics_dict[algo].keys():
        logging.info(f'Expl mult: {expl_mult}')
        for metric in  metrics_dict[algo][expl_mult].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][expl_mult][metric])} +- {np.std(metrics_dict[algo][expl_mult][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][expl_mult][metric])}, {np.max(metrics_dict[algo][expl_mult][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: UCB
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.2090609820339332 +- 0.12608705604372852
# INFO:root:interval:  [0.0, 0.41025641025641024]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.7774120350771898 +- 0.378876348132499
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.21622911694510738 +- 0.13377849409579565
# INFO:root:interval:  [0.0, 0.45584725536992843]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.36226617133504285 +- 0.09057426032417826
# INFO:root:interval:  [0.0, 0.4622222222222222]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.7838685570109065 +- 0.20245853328411176
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.4141288782816229 +- 0.10489605235688376
# INFO:root:interval:  [0.0, 0.5035799522673031]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: regTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.32773269689737466 +- 0.031742925325099966
# INFO:root:interval:  [0.23389021479713604, 0.4343675417661098]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 1.0 +- 0.0
# INFO:root:interval:  [1.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.32773269689737466 +- 0.031742925325099966
# INFO:root:interval:  [0.23389021479713604, 0.4343675417661098]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.43572111075231745 +- 0.05055980634560748
# INFO:root:interval:  [0.29832935560859186, 0.5083532219570406]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.9911393773492025 +- 0.026432401194800413
# INFO:root:interval:  [0.8776371308016878, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.4380906921241049 +- 0.05317036788181897
# INFO:root:interval:  [0.29832935560859186, 0.513126491646778]
# INFO:root:============================================
# INFO:root:============================================
# INFO:root:Algo: lenientTS
# INFO:root:Expl mult: 1
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.11975344339005786 +- 0.11681270754758454
# INFO:root:interval:  [0.0, 0.3126491646778043]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.5169634514266518 +- 0.485674573869837
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.12353221957040572 +- 0.12288324623856493
# INFO:root:interval:  [0.0, 0.3532219570405728]
# INFO:root:============================================
# INFO:root:Expl mult: 10
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.11203453215974163 +- 0.112695244144616
# INFO:root:interval:  [0.0, 0.32489451476793246]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.545579332947754 +- 0.48895797120563594
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.11451073985680191 +- 0.11723843200161847
# INFO:root:interval:  [0.0, 0.36754176610978523]
# INFO:root:============================================
# INFO:root:============================================

# %% [markdown]
# ## Test avec dropout plutot que bonus d'exploration

# %%
metrics_dict = {}
algos = ["regTS"]
logging.info(metrics_dict)
max_n_steps = 10
for algo in algos:
    metrics_dict[algo] = {}
    for dropout_rate in [0.2, 0.5, 0.8]:
        metrics_dict[algo][str(dropout_rate)] = {}
        metrics_dict[algo][str(dropout_rate)]["jaccards"] = []
        metrics_dict[algo][str(dropout_rate)]["percent_inter"] = []
        metrics_dict[algo][str(dropout_rate)]["percent_found"] = []
        metrics_dict[algo][str(dropout_rate)]["fails"] = 0
        b = 0

        for i in range(b, 50):
            logging.info(f"at algo: {algo}, dropout: {dropout_rate}, run: {i}")
            make_deterministic(seed=i)
            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)
            n_trials = 500
            width = 100
            net = NetworkDropout(d, width).to(device)
            reg = 1
            sampletype = "f"
            reward_fn = reward_fn
            de_config = DEConfig
            de_policy = PullPolicy
            bern_p = 1 - dropout_rate
            p_vec = torch.tensor([bern_p] * width)

            if algo == "UCB":
                agent = DENeuralTSDiag(
                    net, lambda_=reg, style="ucb", sampletype=sampletype
                )
            elif algo == "regTS":
                agent = DENeuralTSDiag(
                    net, lambda_=reg, style="ts", sampletype=sampletype
                )
            elif algo == "lenientTS":
                agent = LenientDENeuralTSDiag(
                    reward_sample_thresholds=[float("-inf"), 0],
                    net=net,
                    lambda_=reg,
                    sampletype=sampletype,
                )

            vecs, rewards = gen_warmup_vecs_and_rewards(10)
            vecs, rewards = vecs.to(device), rewards.to(device)

            # Warmup
            for j in range(len(rewards)):
                agent.vec_history = vecs[: j + 1]
                agent.reward_history = rewards[: j + 1]

                if sampletype == "f":
                    eval_mask = (
                        torch.distributions.Bernoulli(
                            p_vec,
                        ).sample()
                        / bern_p  # Rescales the output by 1 - dropout, like the dropout layer of pytorch
                    ).to(device)

                    agent.net.set_mask(eval_mask)
                vec = vecs[j]
                activ, grad = agent.compute_activation_and_grad(vec)
                agent.U += grad * grad
                if sampletype == "f":
                    training_mask = (
                        torch.distributions.Bernoulli(
                            p_vec.repeat(agent.reward_history.shape[0], 1)
                        ).sample()
                        / bern_p  # Rescales the output by 1 - dropout, like the dropout layer of pytorch
                    ).to(device)

                    agent.net.set_mask(training_mask)

                agent.train(j + 1)

            # Train
            for j in range(n_trials):
                if sampletype == "f":
                    eval_mask = (
                        torch.distributions.Bernoulli(
                            p_vec,
                        ).sample()
                        / bern_p  # Rescales the output by 1 - dropout, like the dropout layer of pytorch
                    ).to(device)

                    agent.net.set_mask(eval_mask)

                best_member = find_best_member(agent.get_sample, de_config=de_config, seed=j)
                best_member_grad = best_member.activation_grad
                a_t = best_member.point.unsqueeze(0)
                r_t = reward_fn(a_t).unsqueeze(0).unsqueeze(0)

                if best_member_grad is None:
                    break
                agent.U += best_member_grad * best_member_grad

                agent.vec_history = torch.cat((agent.vec_history, a_t))
                agent.reward_history = torch.cat((agent.reward_history, r_t))

                if sampletype == "f":
                    training_mask = (
                        torch.distributions.Bernoulli(
                            p_vec.repeat(agent.reward_history.shape[0], 1)
                        ).sample()
                        / bern_p  # Rescales the output by 1 - dropout, like the dropout layer of pytorch
                    ).to(device)

                    agent.net.set_mask(training_mask)

                n_steps = min(agent.reward_history.shape[0], max_n_steps)
                agent.train(n_steps)

            if best_member_grad is None:
                metrics_dict[algo][str(dropout_rate)]["fails"] += 1
                logging.info(
                    f"Encountered a fail in {algo} {dropout_rate} because of nans"
                )
                continue
            # Stop using mask in eval
            agent.net.set_mask(None)
            sol, _, _ = agent.find_solution_in_vecs(x, 0)
            sol = sol.to(device)
            n_sol = len(sol)

            jaccard, n_inter = compute_jaccard(sol, true_sol)
            percent_found = n_inter / n_true_sol
            if n_sol == 0:
                percent_inter = 0
            else:
                percent_inter = n_inter / n_sol

            metrics_dict[algo][str(dropout_rate)]["jaccards"].append(jaccard)
            metrics_dict[algo][str(dropout_rate)]["percent_inter"].append(percent_inter)
            metrics_dict[algo][str(dropout_rate)]["percent_found"].append(percent_found)

            if percent_found == 0:
                logging.info(f"Found no solution for run {i}")
                metrics_dict[algo][str(dropout_rate)]["fails"] += 1

                plot_estimate(
                    agent,
                    n_trials,
                    fn=f"no_sol_{algo}_drop_{dropout_rate}_100_trials_seed_{i}.png",
                )

            logging.info(
                f"jaccard: {jaccard}, percent_inter: {percent_inter}, percent_found: {percent_found}"
            )

torch.save(metrics_dict, f"metrics_dict_exp_synth_{max_n_steps}_dropout.pth")
# Out:
# INFO:root:{}
# INFO:root:at algo: regTS, dropout: 0.2, run: 0
# INFO:root:jaccard: 0.29594272076372313, percent_inter: 1.0, percent_found: 0.29594272076372313
# INFO:root:at algo: regTS, dropout: 0.2, run: 1
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.2, run: 2
# INFO:root:jaccard: 0.2446351931330472, percent_inter: 0.7080745341614907, percent_found: 0.2720763723150358
# INFO:root:at algo: regTS, dropout: 0.2, run: 3
# INFO:root:jaccard: 0.30071599045346065, percent_inter: 1.0, percent_found: 0.30071599045346065
# INFO:root:at algo: regTS, dropout: 0.2, run: 4
# INFO:root:jaccard: 0.4081145584725537, percent_inter: 1.0, percent_found: 0.4081145584725537
# INFO:root:at algo: regTS, dropout: 0.2, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 6
# INFO:root:jaccard: 0.26146788990825687, percent_inter: 0.8702290076335878, percent_found: 0.2720763723150358
# INFO:root:at algo: regTS, dropout: 0.2, run: 7
# INFO:root:jaccard: 0.38663484486873506, percent_inter: 1.0, percent_found: 0.38663484486873506
# INFO:root:at algo: regTS, dropout: 0.2, run: 8
# INFO:root:Found no solution for run 8
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 9
# INFO:root:jaccard: 0.3436754176610978, percent_inter: 1.0, percent_found: 0.3436754176610978
# INFO:root:at algo: regTS, dropout: 0.2, run: 10
# INFO:root:Found no solution for run 10
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 11
# INFO:root:jaccard: 0.36666666666666664, percent_inter: 0.8418367346938775, percent_found: 0.3937947494033413
# INFO:root:at algo: regTS, dropout: 0.2, run: 12
# INFO:root:Found no solution for run 12
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 14
# INFO:root:jaccard: 0.2863961813842482, percent_inter: 1.0, percent_found: 0.2863961813842482
# INFO:root:at algo: regTS, dropout: 0.2, run: 15
# INFO:root:jaccard: 0.3813953488372093, percent_inter: 0.9371428571428572, percent_found: 0.3914081145584726
# INFO:root:at algo: regTS, dropout: 0.2, run: 16
# INFO:root:jaccard: 0.431980906921241, percent_inter: 1.0, percent_found: 0.431980906921241
# INFO:root:at algo: regTS, dropout: 0.2, run: 17
# INFO:root:jaccard: 0.3556085918854415, percent_inter: 1.0, percent_found: 0.3556085918854415
# INFO:root:at algo: regTS, dropout: 0.2, run: 18
# INFO:root:jaccard: 0.4028103044496487, percent_inter: 0.9555555555555556, percent_found: 0.4105011933174224
# INFO:root:at algo: regTS, dropout: 0.2, run: 19
# INFO:root:jaccard: 0.3793103448275862, percent_inter: 0.9116022099447514, percent_found: 0.3937947494033413
# INFO:root:at algo: regTS, dropout: 0.2, run: 20
# INFO:root:jaccard: 0.22195704057279236, percent_inter: 1.0, percent_found: 0.22195704057279236
# INFO:root:at algo: regTS, dropout: 0.2, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 22
# INFO:root:jaccard: 0.2824267782426778, percent_inter: 0.6958762886597938, percent_found: 0.3221957040572792
# INFO:root:at algo: regTS, dropout: 0.2, run: 23
# INFO:root:jaccard: 0.2840095465393795, percent_inter: 1.0, percent_found: 0.2840095465393795
# INFO:root:at algo: regTS, dropout: 0.2, run: 24
# INFO:root:Found no solution for run 24
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 25
# INFO:root:jaccard: 0.28878281622911695, percent_inter: 1.0, percent_found: 0.28878281622911695
# INFO:root:at algo: regTS, dropout: 0.2, run: 26
# INFO:root:jaccard: 0.28162291169451076, percent_inter: 1.0, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, dropout: 0.2, run: 27
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, dropout: 0.2, run: 28
# INFO:root:jaccard: 0.34844868735083534, percent_inter: 1.0, percent_found: 0.34844868735083534
# INFO:root:at algo: regTS, dropout: 0.2, run: 29
# INFO:root:jaccard: 0.2744630071599045, percent_inter: 1.0, percent_found: 0.2744630071599045
# INFO:root:at algo: regTS, dropout: 0.2, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 32
# INFO:root:jaccard: 0.3031026252983294, percent_inter: 1.0, percent_found: 0.3031026252983294
# INFO:root:at algo: regTS, dropout: 0.2, run: 33
# INFO:root:Found no solution for run 33
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 34
# INFO:root:jaccard: 0.29832935560859186, percent_inter: 1.0, percent_found: 0.29832935560859186
# INFO:root:at algo: regTS, dropout: 0.2, run: 35
# INFO:root:jaccard: 0.20763723150357996, percent_inter: 1.0, percent_found: 0.20763723150357996
# INFO:root:at algo: regTS, dropout: 0.2, run: 36
# INFO:root:Found no solution for run 36
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 37
# INFO:root:Found no solution for run 37
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 38
# INFO:root:jaccard: 0.24390243902439024, percent_inter: 0.7746478873239436, percent_found: 0.26252983293556087
# INFO:root:at algo: regTS, dropout: 0.2, run: 39
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, dropout: 0.2, run: 40
# INFO:root:Found no solution for run 40
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 41
# INFO:root:jaccard: 0.2935560859188544, percent_inter: 1.0, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, dropout: 0.2, run: 42
# INFO:root:jaccard: 0.2720763723150358, percent_inter: 1.0, percent_found: 0.2720763723150358
# INFO:root:at algo: regTS, dropout: 0.2, run: 43
# INFO:root:jaccard: 0.16757741347905283, percent_inter: 0.4144144144144144, percent_found: 0.21957040572792363
# INFO:root:at algo: regTS, dropout: 0.2, run: 44
# INFO:root:jaccard: 0.43675417661097854, percent_inter: 1.0, percent_found: 0.43675417661097854
# INFO:root:at algo: regTS, dropout: 0.2, run: 45
# INFO:root:jaccard: 0.24105011933174225, percent_inter: 1.0, percent_found: 0.24105011933174225
# INFO:root:at algo: regTS, dropout: 0.2, run: 46
# INFO:root:jaccard: 0.33651551312649164, percent_inter: 1.0, percent_found: 0.33651551312649164
# INFO:root:at algo: regTS, dropout: 0.2, run: 47
# INFO:root:Found no solution for run 47
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.2, run: 48
# INFO:root:jaccard: 0.35083532219570407, percent_inter: 1.0, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, dropout: 0.2, run: 49
# INFO:root:jaccard: 0.3770491803278688, percent_inter: 0.9526627218934911, percent_found: 0.38424821002386633
# INFO:root:at algo: regTS, dropout: 0.5, run: 0
# INFO:root:jaccard: 0.3595238095238095, percent_inter: 0.993421052631579, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, dropout: 0.5, run: 1
# INFO:root:jaccard: 0.4409090909090909, percent_inter: 0.9023255813953488, percent_found: 0.4630071599045346
# INFO:root:at algo: regTS, dropout: 0.5, run: 2
# INFO:root:jaccard: 0.27256637168141595, percent_inter: 0.5133333333333333, percent_found: 0.36754176610978523
# INFO:root:at algo: regTS, dropout: 0.5, run: 3
# INFO:root:jaccard: 0.3460620525059666, percent_inter: 1.0, percent_found: 0.3460620525059666
# INFO:root:at algo: regTS, dropout: 0.5, run: 4
# INFO:root:jaccard: 0.4588235294117647, percent_inter: 0.9701492537313433, percent_found: 0.46539379474940334
# INFO:root:at algo: regTS, dropout: 0.5, run: 5
# INFO:root:Found no solution for run 5
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 6
# INFO:root:jaccard: 0.22701949860724233, percent_inter: 0.3528138528138528, percent_found: 0.38902147971360385
# INFO:root:at algo: regTS, dropout: 0.5, run: 7
# INFO:root:jaccard: 0.4357298474945534, percent_inter: 0.8333333333333334, percent_found: 0.477326968973747
# INFO:root:at algo: regTS, dropout: 0.5, run: 8
# INFO:root:Found no solution for run 8
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 9
# INFO:root:jaccard: 0.4343675417661098, percent_inter: 1.0, percent_found: 0.4343675417661098
# INFO:root:at algo: regTS, dropout: 0.5, run: 10
# INFO:root:jaccard: 0.00477326968973747, percent_inter: 1.0, percent_found: 0.00477326968973747
# INFO:root:at algo: regTS, dropout: 0.5, run: 11
# INFO:root:jaccard: 0.38209606986899564, percent_inter: 0.8177570093457944, percent_found: 0.41766109785202865
# INFO:root:at algo: regTS, dropout: 0.5, run: 12
# INFO:root:jaccard: 0.002386634844868735, percent_inter: 1.0, percent_found: 0.002386634844868735
# INFO:root:at algo: regTS, dropout: 0.5, run: 13
# INFO:root:Found no solution for run 13
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 14
# INFO:root:jaccard: 0.46808510638297873, percent_inter: 0.9801980198019802, percent_found: 0.47255369928400953
# INFO:root:at algo: regTS, dropout: 0.5, run: 15
# INFO:root:jaccard: 0.4606205250596659, percent_inter: 1.0, percent_found: 0.4606205250596659
# INFO:root:at algo: regTS, dropout: 0.5, run: 16
# INFO:root:jaccard: 0.43914081145584727, percent_inter: 1.0, percent_found: 0.43914081145584727
# INFO:root:at algo: regTS, dropout: 0.5, run: 17
# INFO:root:jaccard: 0.44907407407407407, percent_inter: 0.9371980676328503, percent_found: 0.4630071599045346
# INFO:root:at algo: regTS, dropout: 0.5, run: 18
# INFO:root:jaccard: 0.27866473149492016, percent_inter: 0.4155844155844156, percent_found: 0.45823389021479716
# INFO:root:at algo: regTS, dropout: 0.5, run: 19
# INFO:root:jaccard: 0.3412887828162291, percent_inter: 1.0, percent_found: 0.3412887828162291
# INFO:root:at algo: regTS, dropout: 0.5, run: 20
# INFO:root:jaccard: 0.23703703703703705, percent_inter: 0.5140562248995983, percent_found: 0.3054892601431981
# INFO:root:at algo: regTS, dropout: 0.5, run: 21
# INFO:root:Found no solution for run 21
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 22
# INFO:root:jaccard: 0.37957610789980734, percent_inter: 0.6632996632996633, percent_found: 0.4701670644391408
# INFO:root:at algo: regTS, dropout: 0.5, run: 23
# INFO:root:jaccard: 0.3937947494033413, percent_inter: 1.0, percent_found: 0.3937947494033413
# INFO:root:at algo: regTS, dropout: 0.5, run: 24
# INFO:root:jaccard: 0.33614864864864863, percent_inter: 0.5349462365591398, percent_found: 0.47494033412887826
# INFO:root:at algo: regTS, dropout: 0.5, run: 25
# INFO:root:jaccard: 0.43115124153498874, percent_inter: 0.8883720930232558, percent_found: 0.45584725536992843
# INFO:root:at algo: regTS, dropout: 0.5, run: 26
# INFO:root:jaccard: 0.36325678496868474, percent_inter: 0.7435897435897436, percent_found: 0.4152744630071599
# INFO:root:at algo: regTS, dropout: 0.5, run: 27
# INFO:root:jaccard: 0.35752212389380533, percent_inter: 0.5804597701149425, percent_found: 0.4821002386634845
# INFO:root:at algo: regTS, dropout: 0.5, run: 28
# INFO:root:jaccard: 0.4682352941176471, percent_inter: 0.9707317073170731, percent_found: 0.47494033412887826
# INFO:root:at algo: regTS, dropout: 0.5, run: 29
# INFO:root:jaccard: 0.3627684964200477, percent_inter: 1.0, percent_found: 0.3627684964200477
# INFO:root:at algo: regTS, dropout: 0.5, run: 30
# INFO:root:jaccard: 0.0477326968973747, percent_inter: 1.0, percent_found: 0.0477326968973747
# INFO:root:at algo: regTS, dropout: 0.5, run: 31
# INFO:root:jaccard: 0.031026252983293555, percent_inter: 1.0, percent_found: 0.031026252983293555
# INFO:root:at algo: regTS, dropout: 0.5, run: 32
# INFO:root:jaccard: 0.4295942720763723, percent_inter: 1.0, percent_found: 0.4295942720763723
# INFO:root:at algo: regTS, dropout: 0.5, run: 33
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, dropout: 0.5, run: 34
# INFO:root:jaccard: 0.3341288782816229, percent_inter: 1.0, percent_found: 0.3341288782816229
# INFO:root:at algo: regTS, dropout: 0.5, run: 35
# INFO:root:jaccard: 0.3532219570405728, percent_inter: 1.0, percent_found: 0.3532219570405728
# INFO:root:at algo: regTS, dropout: 0.5, run: 36
# INFO:root:Found no solution for run 36
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 37
# INFO:root:jaccard: 0.002386634844868735, percent_inter: 1.0, percent_found: 0.002386634844868735
# INFO:root:at algo: regTS, dropout: 0.5, run: 38
# INFO:root:Found no solution for run 38
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 39
# INFO:root:jaccard: 0.4152744630071599, percent_inter: 1.0, percent_found: 0.4152744630071599
# INFO:root:at algo: regTS, dropout: 0.5, run: 40
# INFO:root:jaccard: 0.011933174224343675, percent_inter: 1.0, percent_found: 0.011933174224343675
# INFO:root:at algo: regTS, dropout: 0.5, run: 41
# INFO:root:jaccard: 0.3794749403341289, percent_inter: 1.0, percent_found: 0.3794749403341289
# INFO:root:at algo: regTS, dropout: 0.5, run: 42
# INFO:root:jaccard: 0.2943327239488117, percent_inter: 0.5570934256055363, percent_found: 0.38424821002386633
# INFO:root:at algo: regTS, dropout: 0.5, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.5, run: 44
# INFO:root:jaccard: 0.47368421052631576, percent_inter: 0.92, percent_found: 0.49403341288782815
# INFO:root:at algo: regTS, dropout: 0.5, run: 45
# INFO:root:jaccard: 0.441527446300716, percent_inter: 1.0, percent_found: 0.441527446300716
# INFO:root:at algo: regTS, dropout: 0.5, run: 46
# INFO:root:jaccard: 0.21241050119331742, percent_inter: 1.0, percent_found: 0.21241050119331742
# INFO:root:at algo: regTS, dropout: 0.5, run: 47
# INFO:root:jaccard: 0.011933174224343675, percent_inter: 1.0, percent_found: 0.011933174224343675
# INFO:root:at algo: regTS, dropout: 0.5, run: 48
# INFO:root:jaccard: 0.19331742243436753, percent_inter: 1.0, percent_found: 0.19331742243436753
# INFO:root:at algo: regTS, dropout: 0.5, run: 49
# INFO:root:jaccard: 0.3893280632411067, percent_inter: 0.6936619718309859, percent_found: 0.4701670644391408
# INFO:root:at algo: regTS, dropout: 0.8, run: 0
# INFO:root:jaccard: 0.18138424821002386, percent_inter: 1.0, percent_found: 0.18138424821002386
# INFO:root:at algo: regTS, dropout: 0.8, run: 1
# INFO:root:jaccard: 0.3232484076433121, percent_inter: 0.49271844660194175, percent_found: 0.48448687350835323
# INFO:root:at algo: regTS, dropout: 0.8, run: 2
# INFO:root:jaccard: 0.22841225626740946, percent_inter: 0.3542116630669546, percent_found: 0.3914081145584726
# INFO:root:at algo: regTS, dropout: 0.8, run: 3
# INFO:root:jaccard: 0.3274336283185841, percent_inter: 0.5589123867069486, percent_found: 0.441527446300716
# INFO:root:at algo: regTS, dropout: 0.8, run: 4
# INFO:root:jaccard: 0.29042904290429045, percent_inter: 0.48484848484848486, percent_found: 0.4200477326968974
# INFO:root:at algo: regTS, dropout: 0.8, run: 5
# INFO:root:jaccard: 0.14558472553699284, percent_inter: 1.0, percent_found: 0.14558472553699284
# INFO:root:at algo: regTS, dropout: 0.8, run: 6
# INFO:root:jaccard: 0.27715877437325903, percent_inter: 0.39959839357429716, percent_found: 0.47494033412887826
# INFO:root:at algo: regTS, dropout: 0.8, run: 7
# INFO:root:jaccard: 0.33448275862068966, percent_inter: 0.5464788732394367, percent_found: 0.4630071599045346
# INFO:root:at algo: regTS, dropout: 0.8, run: 8
# INFO:root:jaccard: 0.2522255192878338, percent_inter: 0.4, percent_found: 0.40572792362768495
# INFO:root:at algo: regTS, dropout: 0.8, run: 9
# INFO:root:jaccard: 0.14081145584725538, percent_inter: 1.0, percent_found: 0.14081145584725538
# INFO:root:at algo: regTS, dropout: 0.8, run: 10
# INFO:root:jaccard: 0.2633863965267728, percent_inter: 0.4008810572687225, percent_found: 0.4343675417661098
# INFO:root:at algo: regTS, dropout: 0.8, run: 11
# INFO:root:jaccard: 0.2052505966587112, percent_inter: 1.0, percent_found: 0.2052505966587112
# INFO:root:at algo: regTS, dropout: 0.8, run: 12
# INFO:root:jaccard: 0.059665871121718374, percent_inter: 1.0, percent_found: 0.059665871121718374
# INFO:root:at algo: regTS, dropout: 0.8, run: 13
# INFO:root:jaccard: 0.16467780429594273, percent_inter: 1.0, percent_found: 0.16467780429594273
# INFO:root:at algo: regTS, dropout: 0.8, run: 14
# INFO:root:Found no solution for run 14
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 15
# INFO:root:jaccard: 0.24512534818941503, percent_inter: 0.3705263157894737, percent_found: 0.4200477326968974
# INFO:root:at algo: regTS, dropout: 0.8, run: 16
# INFO:root:jaccard: 0.2505091649694501, percent_inter: 0.6307692307692307, percent_found: 0.2935560859188544
# INFO:root:at algo: regTS, dropout: 0.8, run: 17
# INFO:root:Found no solution for run 17
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 18
# INFO:root:Found no solution for run 18
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 19
# INFO:root:jaccard: 0.20970042796005706, percent_inter: 0.34265734265734266, percent_found: 0.35083532219570407
# INFO:root:at algo: regTS, dropout: 0.8, run: 20
# INFO:root:jaccard: 0.34364820846905536, percent_inter: 0.5197044334975369, percent_found: 0.5035799522673031
# INFO:root:at algo: regTS, dropout: 0.8, run: 21
# INFO:root:jaccard: 0.07159904534606205, percent_inter: 1.0, percent_found: 0.07159904534606205
# INFO:root:at algo: regTS, dropout: 0.8, run: 22
# INFO:root:jaccard: 0.1909307875894988, percent_inter: 1.0, percent_found: 0.1909307875894988
# INFO:root:at algo: regTS, dropout: 0.8, run: 23
# INFO:root:jaccard: 0.37047353760445684, percent_inter: 0.47079646017699117, percent_found: 0.6348448687350835
# INFO:root:at algo: regTS, dropout: 0.8, run: 24
# INFO:root:jaccard: 0.2458233890214797, percent_inter: 1.0, percent_found: 0.2458233890214797
# INFO:root:at algo: regTS, dropout: 0.8, run: 25
# INFO:root:jaccard: 0.2616279069767442, percent_inter: 0.40089086859688194, percent_found: 0.4295942720763723
# INFO:root:at algo: regTS, dropout: 0.8, run: 26
# INFO:root:jaccard: 0.23694779116465864, percent_inter: 0.5989847715736041, percent_found: 0.28162291169451076
# INFO:root:at algo: regTS, dropout: 0.8, run: 27
# INFO:root:Found no solution for run 27
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 28
# INFO:root:jaccard: 0.27099841521394613, percent_inter: 0.4464751958224543, percent_found: 0.4081145584725537
# INFO:root:at algo: regTS, dropout: 0.8, run: 29
# INFO:root:jaccard: 0.30016863406408095, percent_inter: 0.5056818181818182, percent_found: 0.42482100238663484
# INFO:root:at algo: regTS, dropout: 0.8, run: 30
# INFO:root:Found no solution for run 30
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 31
# INFO:root:Found no solution for run 31
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 32
# INFO:root:Found no solution for run 32
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 33
# INFO:root:jaccard: 0.23374613003095976, percent_inter: 0.3994708994708995, percent_found: 0.360381861575179
# INFO:root:at algo: regTS, dropout: 0.8, run: 34
# INFO:root:jaccard: 0.35097493036211697, percent_inter: 0.4573502722323049, percent_found: 0.6014319809069213
# INFO:root:at algo: regTS, dropout: 0.8, run: 35
# INFO:root:jaccard: 0.3111111111111111, percent_inter: 0.48157248157248156, percent_found: 0.4677804295942721
# INFO:root:at algo: regTS, dropout: 0.8, run: 36
# INFO:root:jaccard: 0.2569832402234637, percent_inter: 0.38253638253638256, percent_found: 0.43914081145584727
# INFO:root:at algo: regTS, dropout: 0.8, run: 37
# INFO:root:jaccard: 0.3316831683168317, percent_inter: 0.5180412371134021, percent_found: 0.4797136038186158
# INFO:root:at algo: regTS, dropout: 0.8, run: 38
# INFO:root:jaccard: 0.16467780429594273, percent_inter: 1.0, percent_found: 0.16467780429594273
# INFO:root:at algo: regTS, dropout: 0.8, run: 39
# INFO:root:jaccard: 0.3345132743362832, percent_inter: 0.564179104477612, percent_found: 0.4510739856801909
# INFO:root:at algo: regTS, dropout: 0.8, run: 40
# INFO:root:jaccard: 0.09069212410501193, percent_inter: 1.0, percent_found: 0.09069212410501193
# INFO:root:at algo: regTS, dropout: 0.8, run: 41
# INFO:root:jaccard: 0.27298850574712646, percent_inter: 0.4068522483940043, percent_found: 0.45346062052505964
# INFO:root:at algo: regTS, dropout: 0.8, run: 42
# INFO:root:jaccard: 0.4251781472684085, percent_inter: 0.988950276243094, percent_found: 0.42720763723150357
# INFO:root:at algo: regTS, dropout: 0.8, run: 43
# INFO:root:Found no solution for run 43
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 44
# INFO:root:jaccard: 0.34958217270194986, percent_inter: 0.45636363636363636, percent_found: 0.5990453460620525
# INFO:root:at algo: regTS, dropout: 0.8, run: 45
# INFO:root:jaccard: 0.27301092043681746, percent_inter: 0.44080604534005036, percent_found: 0.41766109785202865
# INFO:root:at algo: regTS, dropout: 0.8, run: 46
# INFO:root:jaccard: 0.2986217457886677, percent_inter: 0.45454545454545453, percent_found: 0.46539379474940334
# INFO:root:at algo: regTS, dropout: 0.8, run: 47
# INFO:root:jaccard: 0.3816155988857939, percent_inter: 0.4781849912739965, percent_found: 0.6539379474940334
# INFO:root:at algo: regTS, dropout: 0.8, run: 48
# INFO:root:Found no solution for run 48
# INFO:root:jaccard: 0.0, percent_inter: 0, percent_found: 0.0
# INFO:root:at algo: regTS, dropout: 0.8, run: 49
# INFO:root:jaccard: 0.3551532033426184, percent_inter: 0.4602888086642599, percent_found: 0.6085918854415274

# %%
for algo in metrics_dict.keys():
    logging.info(f"Algo: {algo}")
    for dropout_rate in metrics_dict[algo].keys():
        logging.info(f'dropout: {dropout_rate}')
        for metric in  metrics_dict[algo][dropout_rate].keys():
            logging.info(f'Metric: {metric}')
            logging.info(f"mean: {np.mean(metrics_dict[algo][dropout_rate][metric])} +- {np.std(metrics_dict[algo][dropout_rate][metric])} ")
            logging.info(f"interval:  [{np.min(metrics_dict[algo][dropout_rate][metric])}, {np.max(metrics_dict[algo][dropout_rate][metric])}]")
            logging.info("============================================")
        # if 0 in metrics_dict[algo][expl_mult]:
        #     logging.info(f'rerun {metrics_dict[algo][expl_mult][metric].index(0)} with plotting')
    
    logging.info("============================================")
# Out:
# INFO:root:Algo: regTS
# INFO:root:dropout: 0.2
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.2278727548056131 +- 0.15184103834561052
# INFO:root:interval:  [0.0, 0.43675417661097854]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.6812408442284752 +- 0.4370096849708521
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.23217183770883057 +- 0.15353468112726165
# INFO:root:interval:  [0.0, 0.43675417661097854]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 14.0 +- 0.0
# INFO:root:interval:  [14, 14]
# INFO:root:============================================
# INFO:root:dropout: 0.5
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.27010302000221137 +- 0.17590030019324868
# INFO:root:interval:  [0.0, 0.47368421052631576]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.7556464951168753 +- 0.35227476860012236
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.29527446300715987 +- 0.1891347747544062
# INFO:root:interval:  [0.0, 0.49403341288782815]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 7.0 +- 0.0
# INFO:root:interval:  [7, 7]
# INFO:root:============================================
# INFO:root:dropout: 0.8
# INFO:root:Metric: jaccards
# INFO:root:mean: 0.21244472438269607 +- 0.1251555013617156
# INFO:root:interval:  [0.0, 0.4251781472684085]
# INFO:root:============================================
# INFO:root:Metric: percent_inter
# INFO:root:mean: 0.5082655516119939 +- 0.32935753357084846
# INFO:root:interval:  [0.0, 1.0]
# INFO:root:============================================
# INFO:root:Metric: percent_found
# INFO:root:mean: 0.3069689737470167 +- 0.20254580695316549
# INFO:root:interval:  [0.0, 0.6539379474940334]
# INFO:root:============================================
# INFO:root:Metric: fails
# INFO:root:mean: 9.0 +- 0.0
# INFO:root:interval:  [9, 9]
# INFO:root:============================================
# INFO:root:============================================
