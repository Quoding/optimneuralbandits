# %%
import matplotlib.pyplot as plt
import numpy as np

sys.path.append('../viz')

import viz_config

# %%
a = np.load("/home/quo/Documents/Maitrise/optimneuralbandits/testing/debug/metrics/memoire/dataset=500_rx_100000_combis_10_patterns_5/width=128/hidden=1/n_obs=20000/decay=0/lr=plateau/custom_layers=None/reweight=True/batch_size=512/dropout_rate=None/loss=['mse']/classif_thresh=None/batch_norm=True/patience=25/validation=bins/modif=early_stop_patiences_nol2/test_losses.npy")

# %%
x = np.arange(len(a[0]))
plt.plot(x, a[0])
plt.xlabel("Époque")
plt.ylabel("Perte en test")
plt.savefig("../viz/images/supervised/example_low_loss_bad_rep_LOSS.png")
